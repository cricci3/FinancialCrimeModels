# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
from functions.SQUIC_functions import squic_fit_sparse, check_symmetric_sparse
from networkx.algorithms import community
import igraph as ig
import leidenalg as la
from sklearn.cluster import DBSCAN
from functions.spectral_clustering import find_optimal_clusters, compute_spectral_clustering
from functions.internal import load_dataset_1B
from functions.cosmograph_functions import cosmograph_from_theta, cosmograph_decomposition
import os
from matplotlib.gridspec import GridSpec
from functions.plots import plot_timeseries

# %%
def internal_density(G, community, n, density_sum):
    subgraph = G.subgraph(community)
    m = subgraph.number_of_edges()
    max_possible = n * (n - 1) / 2
    density_sum += m / max_possible # internal density of single comm
    return density_sum


def labels_to_partition(labels):
    """Convert label array [0,0,1,1,2,2] -> list of sets [{0,1},{2,3},{4,5}]"""
    clusters = {}
    for idx, label in enumerate(labels):
        if label not in clusters:
            clusters[label] = set()
        clusters[label].add(idx)

    # Remove noise points if using DBSCAN (-1 labels)
    if -1 in clusters:
        noise_nodes = clusters.pop(-1)
        for node in noise_nodes:
            clusters[f'noise_{node}'] = {node}  # unique labels for noise

    return list(clusters.values())


def compute_partition_density(G, community, D_sum):
    n_alpha = len(community)

    subgraph = G.subgraph(community)
    m_alpha = subgraph.number_of_edges()

    numerator = m_alpha - (n_alpha - 1)
    denominator = (n_alpha - 2) * (n_alpha - 1)

    if denominator > 0:
        D_sum += m_alpha * (numerator / denominator)
    return D_sum

# %%
SAVE_FIG_DIR = 'decomposition/glasso_images/amlsim'
PLOT = False
SAVE_FIG = False
SEASONAL_PERIOD = 7

# %%
Y, _, dim, _ = load_dataset_1B()

# if PLOT:
#     plot_timeseries(Y, "AMLSIM", dimension=dim, save_fig=SAVE_FIG_DIR, title="timeseries")

all_residuals = { 
            account: seasonal_decompose(Y[account], model='additive', period=SEASONAL_PERIOD).resid
            for account in Y.columns
        }
df_residuals = pd.DataFrame(all_residuals).dropna()
print(f"Data with {df_residuals.shape[0]} samples after decomposition.")

print("-> Standardizing (normalizing) data...")
residuals_matrix = df_residuals.values
col_std = np.std(residuals_matrix, axis=0, keepdims=True)
col_std[col_std == 0] = 1.0
prepared_data = residuals_matrix / col_std

df_prepared = pd.DataFrame(prepared_data, 
                            index=df_residuals.index, 
                            columns=df_residuals.columns)
# if PLOT:
#     plot_timeseries(df_prepared, "AMLSIM", dimension=dim, save_fig=SAVE_FIG_DIR, title="timeseries_norm")

if dim == '100':
    ROWS = 100
elif dim == '1K':
    ROWS = 1000
elif dim == '10K':
    ROWS = 10000
elif dim == '100K':
    ROWS = 100000

print(prepared_data.shape)
prepared_data = prepared_data.T

print(prepared_data.shape)

# reg. parameter glasso
if dim == '100':
    # lambdas = [0.4, 0.3, 0.2, 0.1, 0.09, 0.07, 0.05, 0.02]
    lambdas = [0.4, 0.2, 0.1, 0.07, 0.05]
elif dim == '1K':
    lambdas = [0.999, 0.95, 0.7, 0.5]
elif dim == '10K':
    # lambdas = [0.9999995]
    lambdas = [0.999995, 0.999, 0.995, 0.8]
    # LAMBDA = 0.99
elif dim == '100K':
    # lambdas = [0.995]
    lambdas = [0.99995, 0.9999, 0.9995, 0.999]

int_metrics = {
    rho: {
        'louvain': {},
        'leiden': {},
        'dbscan': {},
        'spectral': {}
    } for rho in lambdas
}

widget_dict = {}
widget_cluster_dict = {}
results_squic = {}

for LAMBDA in lambdas:
    # Run SQUIC-Fit ---
    print(f"-> Running SQUIC-Fit with lambda = {LAMBDA}...")
    model_fit, end_time = squic_fit_sparse(prepared_data, LAMBDA, LAMBDA/10)
    results_squic[LAMBDA] = model_fit
    end_time = round(end_time, 2)
    print(f"required time: {end_time}")

    int_metrics[LAMBDA]['time'] = end_time

    nnz = model_fit.count_nonzero()
    print(f"nnz = {int(nnz)} per rows = {int(nnz)/ROWS}")


    if check_symmetric_sparse(model_fit):
        print(f" Matrix is symmetric per rho {LAMBDA}")
    else:
        print(f" Matrix is not symmetric per rho {LAMBDA}")

    if PLOT:
        plt.figure(figsize=(7, 7))
        plt.spy(model_fit, markersize=5)
        # plt.xlabel("Users", fontsize=18)
        plt.xlabel("Users", fontsize=18)
        plt.ylabel("Users", fontsize=18)

        plt.tick_params(axis='x', labelsize=18)
        plt.tick_params(axis='y', labelsize=18) 
        if SAVE_FIG:
            path = f'{SAVE_FIG_DIR}/{dim}'
            os.makedirs(path, exist_ok=True)
            lambda_str = str(LAMBDA).replace(".", "")
            plt.savefig(f"{path}/squic_fit_{lambda_str}", dpi=300)
        plt.show()

    widget_dict = cosmograph_from_theta(model_fit, LAMBDA, widget_dict)

    dict_cluster = {
        "louvain" : {},
        "spectral" : {},
        "dbscan" : {},
        "leiden" : {}
    }

    dbscan_params_dict = {
        '100' : {'epsilon' : 0.7,
                'min_samples' : 8},
        '1K' : {'epsilon' : 0.7,
                'min_samples' : 3},
        '10K' : {'epsilon' : 0.7,
                'min_samples' : 3},
        '100K' : {'epsilon' : 0.7,
                'min_samples' : 3},
        '1M' : {'epsilon' : 0.7,
                'min_samples' : 3}
    }

    # Ensure all off-diagonal entries are positive
    X = np.abs(model_fit) 

    # Ensure diagonal entries are zero
    X.setdiag(0) # SQUIC_Fit ensure that, SQUIC not, so manually turn into 0

    # Create a graph from matrix X
    G = nx.from_scipy_sparse_array(X)

    connected = nx.is_connected(G)
    print(f"Is G connected for l={LAMBDA}? {connected}")
    if not connected:
        connected_components = nx.connected_components(G)
        component_sizes = [len(c) for c in connected_components]
        print(f"# CC : {len(component_sizes)}")

    # Louvain
    partition_louvain = community.louvain_communities(G)
    dict_cluster['louvain'] = partition_louvain

    # Leiden
    G_igraph = ig.Graph.from_networkx(G)
    partition_leiden = la.find_partition(G_igraph, la.ModularityVertexPartition)
    dict_cluster['leiden'] = partition_leiden

    dbscan = DBSCAN(eps=dbscan_params_dict[dim]['epsilon'],
                        min_samples=dbscan_params_dict[dim]['min_samples'],
                        metric='cosine')
    labels_dbscan = dbscan.fit_predict(X)

    # Convert labels to list of sets
    partition_dbscan = labels_to_partition(labels_dbscan)
    dict_cluster['dbscan'] = partition_dbscan

    # Spectral Clustering
    optimal_k, eigenvectors = find_optimal_clusters(G, dim, plot=False)
    if eigenvectors is not None:
        labels_spectral = compute_spectral_clustering(eigenvectors, optimal_k, method='kmeans', plot=False)
        # Convert labels to list of sets
        partition_spectral = labels_to_partition(labels_spectral)

        dict_cluster['spectral'] = partition_spectral
    else:
        dict_cluster['spectral'] = None

    widget_cluster_dict = cosmograph_decomposition(widget_cluster_dict, model_fit, LAMBDA, dict_cluster)

    for method, partition in dict_cluster.items():

        print(method)

        # Skip if partition is None
        if partition is None:
            print(f"[Warning] No partition for method={method}, lambda={LAMBDA}. Skipping.")

            int_metrics[LAMBDA][method]["p_density"] = 0
            int_metrics[LAMBDA][method]['modularity'] = 0
            int_metrics[LAMBDA][method]['CC'] = 0
            int_metrics[LAMBDA][method]['nCluster'] = 0
            int_metrics[LAMBDA][method]['isolated'] = "all isolated elements"
        else:
            # Ensure all off-diagonal entries are positive
            X = np.abs(X) 

            # Ensure diagonal entries are zero
            X.setdiag(0) # SQUIC_Fit ensure that, SQUIC not, so manually turn into 0

            # G = nx.from_numpy_array(X)
            G = nx.from_scipy_sparse_array(X)
            
            m_total = G.number_of_edges()
            D_sum = 0
            isolated_node = 0
            density_sum = 0

            for comm in partition:
                n = len(comm)
                if n == 1:
                    isolated_node += 1
                    continue
                else:
                    density_sum = internal_density(G, comm, n, density_sum)

                    if n >= 3: # skip communities too small for partition density
                        D_sum = compute_partition_density(G, comm, D_sum)
            
            avg_internal_density = density_sum / len(partition) # avg internal density
            int_metrics[LAMBDA][method]["int_density"] = float(round(avg_internal_density, 2))

            partition_density = (2 / m_total) * D_sum if m_total > 0 else 0
            int_metrics[LAMBDA][method]["p_density"] = float(round(partition_density, 2))

            modularity = community.modularity(G, partition)
            int_metrics[LAMBDA][method]['modularity'] = float(round(modularity, 2))

            int_metrics[LAMBDA][method]["isolated"] = isolated_node
            
            # Connected Components
            int_metrics[LAMBDA][method]['CC'] = nx.number_connected_components(G)

            # N cluster
            int_metrics[LAMBDA][method]['nCluster'] = len(partition)


for rho, results in int_metrics.items():
    print(f"Lambda = {rho}")
    print()
    for method, metrics in results.items():
        if method == 'time':
            pass
        else:
            print(f"    {method} : #Cluster = {metrics['nCluster']}, int_density = {metrics['int_density']}, p_density = {metrics['p_density']}, Q = {metrics['modularity']}")

colors = {
    'louvain':'green',
    'leiden':'orange',
    'spectral':'cornflowerblue',
    'dbscan':'mediumorchid'
}

# figure with a short time panel below
fig = plt.figure(figsize=(8, 8))
gs = GridSpec(nrows=2, ncols=1, height_ratios=[4, 1], hspace=0.05)
ax1 = fig.add_subplot(gs[0, 0])          # Q (left y)
ax2 = ax1.twinx()                         # Pdensity (right y)
ax_time = fig.add_subplot(gs[1, 0], sharex=ax1)

# Collect the sorted unique rho values (λ) for x (equally spaced categories)
all_rhos = sorted(int_metrics.keys())
x_pos_map = {rho: i for i, rho in enumerate(all_rhos)}  # rho -> index 0..N-1

# Methods present in the first rho entry — keep only dict-valued keys (exclude 'time')
first_rho = all_rhos[0]
clustering_methods = [k for k, v in int_metrics[first_rho].items() if isinstance(v, dict)]

# --- Time panel data (seconds) ---
time_values, time_x = [], []
for rho in all_rhos:
    end_time = int_metrics.get(rho, {}).get('time', np.nan)  # float seconds
    # if some entry is missing or NaN, keep NaN (line plot will skip; bar will show 0 if we choose to)
    time_values.append(end_time)
    time_x.append(x_pos_map[rho])

# --- Top panel: Q and Pdensity for each method ---
for method in clustering_methods:
    x_idx, q_vals, pden_vals = [], [], []
    for rho in all_rhos:
        mm = int_metrics.get(rho, {}).get(method, None)
        if not isinstance(mm, dict):
            continue
        pdens = mm.get('p_density', None)
        modularity = mm.get('modularity', None)
        if (pdens is not None) and (modularity is not None):
            x_idx.append(x_pos_map[rho])
            q_vals.append(modularity)
            pden_vals.append(pdens)

    if x_idx:
        c = colors.get(method, 'black')
        ax1.plot(x_idx, q_vals, linestyle='--', marker='o', color=c, label=f'Q {method}')
        ax2.plot(x_idx, pden_vals, linestyle='-', marker='^', color=c, label=f'Pdensity {method}')

# ===== top axes labels & ticks =====
ax1.set_ylabel('Modularity Q', color='black', fontsize=16)
ax2.set_ylabel('Partition Density', color='black', fontsize=16)
ax1.set_xticks(range(len(all_rhos)))
ax1.set_xticklabels([str(r) for r in all_rhos], fontsize=13)
ax1.tick_params(axis='y', labelsize=13)
ax2.tick_params(axis='y', labelsize=13)
ax1.grid(True, axis='y', alpha=0.3)

# unified legend (top plot)
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2,
        loc='upper center', bbox_to_anchor=(0.5, 1.15),
        ncol=4, fontsize=11, frameon=True)

# ===== bottom time panel (seconds) =====
time_values = np.array(time_values, dtype=float)
# bars (replace NaN with 0 for bars; or switch to a line plot to skip NaNs)
ax_time.bar(time_x, np.nan_to_num(time_values, nan=0.0),
            width=0.6, alpha=0.6, linewidth=0.5)

ax_time.set_ylabel('Time (s)', fontsize=14)
ax_time.set_xlabel(r'Reg. parameter $\lambda$', fontsize=16)
ax_time.tick_params(axis='x', labelsize=13)
ax_time.tick_params(axis='y', labelsize=12)
ax_time.grid(True, axis='y', alpha=0.2)

# hide duplicated x tick labels on top axis
plt.setp(ax1.get_xticklabels(), visible=False)

fig.tight_layout()
if SAVE_FIG:
    path = f'{SAVE_FIG_DIR}/{dim}'
    os.makedirs(path, exist_ok=True)
    plt.savefig(f'{path}/plot', dpi=300)
plt.show()
# Out:
# Data with 194 samples after decomposition.
# -> Standardizing (normalizing) data...
# (194, 1000)
# (1000, 194)
# -> Running SQUIC-Fit with lambda = 0.999...
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    ignored
#  Y:           1000 x 194
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      9.990000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * sample covariance matrix S: time=5.53e-03 nnz(S)/p=1.21e+00
# * iter=1 time=4.60e-03 obj=1.69e+03 |delta(obj)|/obj=4.09e-01 nnz(X,L,W)/p=[1.21e+00 6.10e-01 1.00e+00] lns_iter=2
# * iter=2 time=2.81e-03 obj=1.69e+03 |delta(obj)|/obj=4.61e-08 nnz(X,L,W)/p=[1.21e+00 6.10e-01 1.00e+00] lns_iter=1
# #SQUIC Finished: time=1.35e-02 nnz(X,W)/p=[1.21e+00 1.00e+00]
#
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    2.020000e-01
#  Y:         1000 x 194
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      9.990000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=1.21e+00 time=2.48e-03
# * iter=1 time=2.26e-03 obj=1.86e+03 |delta(obj)|/obj=4.64e-01 nnz(X,L,W)/p=[1.21e+00 6.10e-01 1.20e+00] lns_iter=4
# * iter=2 time=2.90e-03 obj=1.74e+03 |delta(obj)|/obj=7.17e-02 nnz(X,L,W)/p=[1.21e+00 6.10e-01 1.21e+00] lns_iter=3
# * iter=3 time=3.90e-03 obj=1.69e+03 |delta(obj)|/obj=2.86e-02 nnz(X,L,W)/p=[1.21e+00 6.10e-01 1.22e+00] lns_iter=1
# * iter=4 time=3.89e-03 obj=1.67e+03 |delta(obj)|/obj=9.90e-03 nnz(X,L,W)/p=[1.21e+00 6.10e-01 1.22e+00] lns_iter=1
# * iter=5 time=3.79e-03 obj=1.67e+03 |delta(obj)|/obj=3.07e-04 nnz(X,L,W)/p=[1.21e+00 6.10e-01 1.22e+00] lns_iter=1
# #SQUIC Finished: time=1.96e-02 nnz(X,W)/p=[1.21e+00 1.22e+00]
#
# required time: 0.05
# nnz = 202 per rows = 0.202
#  Matrix is symmetric per rho 0.999
# Is G connected for l=0.999? False
# # CC : 930
# louvain
# spectral
# dbscan
# leiden
# -> Running SQUIC-Fit with lambda = 0.95...
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    ignored
#  Y:           1000 x 194
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      9.500000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * sample covariance matrix S: time=2.22e-03 nnz(S)/p=2.33e+00
# * iter=1 time=7.65e-03 obj=1.67e+03 |delta(obj)|/obj=4.01e-01 nnz(X,L,W)/p=[2.33e+00 1.26e+00 1.00e+00] lns_iter=2
# * iter=2 time=1.17e-02 obj=1.67e+03 |delta(obj)|/obj=0.00e+00 nnz(X,L,W)/p=[2.33e+00 1.26e+00 2.31e+00] lns_iter=1
# #SQUIC Finished: time=2.22e-02 nnz(X,W)/p=[2.33e+00 2.31e+00]
#
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    1.218000e+00
#  Y:         1000 x 194
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      9.500000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=2.33e+00 time=8.70e-03
# * iter=1 time=9.20e-03 obj=1.84e+03 |delta(obj)|/obj=4.56e-01 nnz(X,L,W)/p=[2.33e+00 1.26e+00 1.09e+00] lns_iter=5
# * iter=2 time=1.12e-02 obj=1.76e+03 |delta(obj)|/obj=4.59e-02 nnz(X,L,W)/p=[2.33e+00 1.26e+00 2.42e+00] lns_iter=5
# * iter=3 time=4.67e-03 obj=1.60e+03 |delta(obj)|/obj=9.88e-02 nnz(X,L,W)/p=[2.33e+00 1.26e+00 2.52e+00] lns_iter=2
# * iter=4 time=4.20e-03 obj=1.59e+03 |delta(obj)|/obj=7.66e-03 nnz(X,L,W)/p=[2.39e+00 1.26e+00 2.52e+00] lns_iter=1
# * iter=5 time=4.74e-03 obj=1.58e+03 |delta(obj)|/obj=1.99e-03 nnz(X,L,W)/p=[2.39e+00 1.26e+00 2.52e+00] lns_iter=1
# * iter=6 time=5.71e-03 obj=1.58e+03 |delta(obj)|/obj=8.78e-04 nnz(X,L,W)/p=[2.39e+00 1.26e+00 2.52e+00] lns_iter=1
# #SQUIC Finished: time=4.91e-02 nnz(X,W)/p=[2.39e+00 2.52e+00]
#
# required time: 0.08
# nnz = 1232 per rows = 1.232
#  Matrix is symmetric per rho 0.95
# Is G connected for l=0.95? False
# # CC : 722
# louvain
# spectral
# dbscan
# leiden
# -> Running SQUIC-Fit with lambda = 0.7...
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    ignored
#  Y:           1000 x 194
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      7.000000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * sample covariance matrix S: time=3.04e-03 nnz(S)/p=7.01e+00
# * iter=1 time=7.76e-03 obj=1.62e+03 |delta(obj)|/obj=3.83e-01 nnz(X,L,W)/p=[7.01e+00 5.35e+00 1.00e+00] lns_iter=4
# * iter=2 time=7.30e-03 obj=1.58e+03 |delta(obj)|/obj=2.90e-02 nnz(X,L,W)/p=[7.01e+00 5.35e+00 7.74e+00] lns_iter=4
# * iter=3 time=7.43e-03 obj=1.53e+03 |delta(obj)|/obj=3.02e-02 nnz(X,L,W)/p=[7.01e+00 5.35e+00 1.22e+01] lns_iter=1
# * iter=4 time=1.05e-02 obj=1.51e+03 |delta(obj)|/obj=1.30e-02 nnz(X,L,W)/p=[7.01e+00 5.35e+00 1.16e+01] lns_iter=1
# * iter=5 time=8.01e-03 obj=1.51e+03 |delta(obj)|/obj=1.13e-03 nnz(X,L,W)/p=[7.01e+00 5.35e+00 1.22e+01] lns_iter=1
# * iter=6 time=1.05e-02 obj=1.51e+03 |delta(obj)|/obj=4.88e-05 nnz(X,L,W)/p=[7.01e+00 5.35e+00 1.24e+01] lns_iter=1
# #SQUIC Finished: time=5.83e-02 nnz(X,W)/p=[7.01e+00 1.24e+01]
#
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    4.148000e+00
#  Y:         1000 x 194
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      7.000000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=7.01e+00 time=2.27e-03
# * iter=1 time=5.04e-03 obj=1.51e+03 |delta(obj)|/obj=3.37e-01 nnz(X,L,W)/p=[7.01e+00 5.35e+00 2.20e+00] lns_iter=5
# * iter=2 time=6.05e-03 obj=1.41e+03 |delta(obj)|/obj=7.20e-02 nnz(X,L,W)/p=[7.01e+00 5.35e+00 1.06e+01] lns_iter=5
# * iter=3 time=9.79e-03 obj=1.33e+03 |delta(obj)|/obj=5.96e-02 nnz(X,L,W)/p=[7.09e+00 5.20e+00 1.65e+01] lns_iter=3
# * iter=4 time=9.47e-03 obj=1.30e+03 |delta(obj)|/obj=1.71e-02 nnz(X,L,W)/p=[7.09e+00 5.20e+00 2.18e+01] lns_iter=1
# * iter=5 time=1.02e-02 obj=1.29e+03 |delta(obj)|/obj=9.50e-03 nnz(X,L,W)/p=[7.24e+00 5.22e+00 2.31e+01] lns_iter=1
# * iter=6 time=2.08e-02 obj=1.29e+03 |delta(obj)|/obj=2.29e-03 nnz(X,L,W)/p=[7.24e+00 5.22e+00 2.32e+01] lns_iter=1
# * iter=7 time=2.02e-02 obj=1.29e+03 |delta(obj)|/obj=8.00e-04 nnz(X,L,W)/p=[7.24e+00 5.22e+00 2.31e+01] lns_iter=1
# #SQUIC Finished: time=8.63e-02 nnz(X,W)/p=[7.24e+00 2.31e+01]
#
# required time: 0.15
# nnz = 4150 per rows = 4.15
#  Matrix is symmetric per rho 0.7
# Is G connected for l=0.7? False
# # CC : 382
# Attempt 1 failed: ARPACK error -1: No convergence (1001 iterations, 6/13 eigenvectors converged)
# louvain
# spectral
# dbscan
# leiden
# -> Running SQUIC-Fit with lambda = 0.5...
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    ignored
#  Y:           1000 x 194
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      5.000000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * sample covariance matrix S: time=2.61e-03 nnz(S)/p=1.59e+01
# * iter=1 time=1.16e-02 obj=1.43e+03 |delta(obj)|/obj=3.02e-01 nnz(X,L,W)/p=[1.59e+01 3.14e+01 1.00e+00] lns_iter=5
# * iter=2 time=9.82e-03 obj=1.40e+03 |delta(obj)|/obj=2.00e-02 nnz(X,L,W)/p=[1.59e+01 3.14e+01 1.71e+01] lns_iter=6
# * iter=3 time=2.51e-02 obj=1.33e+03 |delta(obj)|/obj=5.35e-02 nnz(X,L,W)/p=[1.59e+01 3.14e+01 1.16e+02] lns_iter=3
# * iter=4 time=8.26e-02 obj=1.31e+03 |delta(obj)|/obj=1.35e-02 nnz(X,L,W)/p=[1.59e+01 3.14e+01 1.78e+02] lns_iter=1
# * iter=5 time=1.00e-01 obj=1.31e+03 |delta(obj)|/obj=4.42e-03 nnz(X,L,W)/p=[1.59e+01 3.14e+01 2.08e+02] lns_iter=1
# * iter=6 time=1.29e-01 obj=1.31e+03 |delta(obj)|/obj=6.94e-04 nnz(X,L,W)/p=[1.59e+01 3.14e+01 2.04e+02] lns_iter=1
# #SQUIC Finished: time=3.71e-01 nnz(X,W)/p=[1.59e+01 2.04e+02]
#
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    6.830000e+00
#  Y:         1000 x 194
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      5.000000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=1.59e+01 time=2.74e-03
# * iter=1 time=8.24e-03 obj=1.25e+03 |delta(obj)|/obj=2.03e-01 nnz(X,L,W)/p=[1.59e+01 3.14e+01 3.59e+00] lns_iter=5
# * iter=2 time=1.29e-02 obj=1.22e+03 |delta(obj)|/obj=2.78e-02 nnz(X,L,W)/p=[1.59e+01 3.14e+01 8.34e+01] lns_iter=7
# * iter=3 time=8.74e-02 obj=1.06e+03 |delta(obj)|/obj=1.48e-01 nnz(X,L,W)/p=[1.68e+01 3.30e+01 4.11e+02] lns_iter=3
# * iter=4 time=3.00e-01 obj=1.03e+03 |delta(obj)|/obj=3.09e-02 nnz(X,L,W)/p=[2.10e+01 3.97e+01 3.69e+02] lns_iter=2
# * iter=5 time=2.65e-01 obj=1.01e+03 |delta(obj)|/obj=1.71e-02 nnz(X,L,W)/p=[2.19e+01 4.13e+01 4.35e+02] lns_iter=1
# * iter=6 time=2.82e-01 obj=1.01e+03 |delta(obj)|/obj=7.09e-03 nnz(X,L,W)/p=[2.19e+01 4.17e+01 4.43e+02] lns_iter=1
# * iter=7 time=2.16e-01 obj=1.00e+03 |delta(obj)|/obj=2.67e-03 nnz(X,L,W)/p=[2.19e+01 4.17e+01 4.48e+02] lns_iter=1
# * iter=8 time=1.86e-01 obj=1.00e+03 |delta(obj)|/obj=1.41e-03 nnz(X,L,W)/p=[2.19e+01 4.36e+01 4.48e+02] lns_iter=1
# * iter=9 time=2.19e-01 obj=1.00e+03 |delta(obj)|/obj=9.93e-04 nnz(X,L,W)/p=[2.19e+01 4.36e+01 4.48e+02] lns_iter=1
# #SQUIC Finished: time=1.60e+00 nnz(X,W)/p=[2.19e+01 4.48e+02]
#
# required time: 1.98
# nnz = 6874 per rows = 6.874
#  Matrix is symmetric per rho 0.5
# Is G connected for l=0.5? False
# # CC : 120
# louvain
# spectral
# dbscan
# leiden
# Lambda = 0.999
#
#     louvain : #Cluster = 930, int_density = 0.12, p_density = 0.38, Q = 0.97
#     leiden : #Cluster = 930, int_density = 0.12, p_density = 0.38, Q = 0.97
#     dbscan : #Cluster = 961, int_density = 0.03, p_density = 0.35, Q = 0.57
#     spectral : #Cluster = 2, int_density = 0.1, p_density = 0.01, Q = 0.4
# Lambda = 0.95
#
#     louvain : #Cluster = 722, int_density = 0.31, p_density = 1.06, Q = 0.98
#     leiden : #Cluster = 722, int_density = 0.31, p_density = 1.06, Q = 0.98
#     dbscan : #Cluster = 768, int_density = 0.13, p_density = 1.03, Q = 0.84
#     spectral : #Cluster = 2, int_density = 0.03, p_density = 0.01, Q = 0.46
# Lambda = 0.7
#
#     louvain : #Cluster = 383, int_density = 0.59, p_density = 0.94, Q = 0.98
#     leiden : #Cluster = 386, int_density = 0.59, p_density = 1.02, Q = 0.98
#     dbscan : #Cluster = 433, int_density = 0.25, p_density = 0.91, Q = 0.92
#     spectral : #Cluster = 5, int_density = 0.05, p_density = 0.03, Q = 0.78
# Lambda = 0.5
#
#     louvain : #Cluster = 144, int_density = 0.72, p_density = 0.39, Q = 0.89
#     leiden : #Cluster = 144, int_density = 0.72, p_density = 0.4, Q = 0.89
#     dbscan : #Cluster = 150, int_density = 0.25, p_density = 0.14, Q = 0.43
#     spectral : #Cluster = 5, int_density = 0.15, p_density = 0.02, Q = 0.42
# /var/folders/s6/4jprwbqj4012tkll2ww6r5hr0000gq/T/ipykernel_10043/1405295996.py:316: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %%
widget_dict
# Out:
# {0.999: Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color='#0d5da4', point_size_by='degree', random_seed=None),
#  0.95: Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color='#0d5da4', point_size_by='degree', random_seed=None),
#  0.7: Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color='#0d5da4', point_size_by='degree', random_seed=None),
#  0.5: Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color='#0d5da4', point_size_by='degree', random_seed=None)}

# %%
rho = 0.7

# %%
widget_dict[rho]
# Out:
# Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_colo…

# %%
widget_cluster_dict
# Out:
# {0.999: {'louvain': Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color=None, point_color_by='community', point_color_by_map=[['0', '#4682B4'], ['1', '#FF9999'], ['2', '#4169E1'], ['3', '#FFD700'], ['4', '#FFCC99'], ['5', '#CCFFE5'], ['6', '#FFFF99'], ['7', '#CCFF99'], ['8', '#CCFFFF'], ['9', '#CCCCFF'], ['10', '#E9967A'], ['11', '#E5CCFF'], ['12', '#DC143C'], ['13', '#FFFFFF'], ['14', '#F0FFF0']], point_color_strategy='map', point_size_by='degree', random_seed=None),
#   'leiden': Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color=None, point_color_by='community', point_color_by_map=[['0', '#4682B4'], ['1', '#FF9999'], ['2', '#4169E1'], ['3', '#FFD700'], ['4', '#FFCC99'], ['5', '#CCFFE5'], ['6', '#FFFF99'], ['7', '#CCFF99'], ['8', '#CCFFFF'], ['9', '#CCCCFF'], ['10', '#E9967A'], ['11', '#E5CCFF'], ['12', '#DC143C'], ['13', '#FFFFFF'], ['14', '#F0FFF0']], point_color_strategy='map', point_size_by='degree', random_seed=None),
#   'dbscan': Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color=None, point_color_by='community', point_color_by_map=[['0', '#4682B4'], ['1', '#FF9999'], ['2', '#4169E1'], ['3', '#FFD700'], ['4', '#FFCC99'], ['5', '#CCFFE5'], ['6', '#FFFF99'], ['7', '#CCFF99'], ['8', '#CCFFFF'], ['9', '#CCCCFF'], ['10', '#E9967A'], ['11', '#E5CCFF'], ['12', '#DC143C'], ['13', '#FFFFFF'], ['14', '#F0FFF0']], point_color_strategy='map', point_size_by='degree', random_seed=None),
#   'spectral': Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color=None, point_color_by='community', point_color_by_map=[['0', '#4682B4'], ['1', '#FF9999'], ['2', '#4169E1'], ['3', '#FFD700'], ['4', '#FFCC99'], ['5', '#CCFFE5'], ['6', '#FFFF99'], ['7', '#CCFF99'], ['8', '#CCFFFF'], ['9', '#CCCCFF'], ['10', '#E9967A'], ['11', '#E5CCFF'], ['12', '#DC143C'], ['13', '#FFFFFF'], ['14', '#F0FFF0']], point_color_strategy='map', point_size_by='degree', random_seed=None)},
#  0.95: {'louvain': Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color=None, point_color_by='community', point_color_by_map=[['0', '#4682B4'], ['1', '#FF9999'], ['2', '#4169E1'], ['3', '#FFD700'], ['4', '#FFCC99'], ['5', '#CCFFE5'], ['6', '#FFFF99'], ['7', '#CCFF99'], ['8', '#CCFFFF'], ['9', '#CCCCFF'], ['10', '#E9967A'], ['11', '#E5CCFF'], ['12', '#DC143C'], ['13', '#FFFFFF'], ['14', '#F0FFF0']], point_color_strategy='map', point_size_by='degree', random_seed=None),
#   'leiden': Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color=None, point_color_by='community', point_color_by_map=[['0', '#4682B4'], ['1', '#FF9999'], ['2', '#4169E1'], ['3', '#FFD700'], ['4', '#FFCC99'], ['5', '#CCFFE5'], ['6', '#FFFF99'], ['7', '#CCFF99'], ['8', '#CCFFFF'], ['9', '#CCCCFF'], ['10', '#E9967A'], ['11', '#E5CCFF'], ['12', '#DC143C'], ['13', '#FFFFFF'], ['14', '#F0FFF0']], point_color_strategy='map', point_size_by='degree', random_seed=None),
#   'dbscan': Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color=None, point_color_by='community', point_color_by_map=[['0', '#4682B4'], ['1', '#FF9999'], ['2', '#4169E1'], ['3', '#FFD700'], ['4', '#FFCC99'], ['5', '#CCFFE5'], ['6', '#FFFF99'], ['7', '#CCFF99'], ['8', '#CCFFFF'], ['9', '#CCCCFF'], ['10', '#E9967A'], ['11', '#E5CCFF'], ['12', '#DC143C'], ['13', '#FFFFFF'], ['14', '#F0FFF0']], point_color_strategy='map', point_size_by='degree', random_seed=None),
#   'spectral': Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color=None, point_color_by='community', point_color_by_map=[['0', '#4682B4'], ['1', '#FF9999'], ['2', '#4169E1'], ['3', '#FFD700'], ['4', '#FFCC99'], ['5', '#CCFFE5'], ['6', '#FFFF99'], ['7', '#CCFF99'], ['8', '#CCFFFF'], ['9', '#CCCCFF'], ['10', '#E9967A'], ['11', '#E5CCFF'], ['12', '#DC143C'], ['13', '#FFFFFF'], ['14', '#F0FFF0']], point_color_strategy='map', point_size_by='degree', random_seed=None)},
#  0.7: {'louvain': Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color=None, point_color_by='community', point_color_by_map=[['0', '#4682B4'], ['1', '#FF9999'], ['2', '#4169E1'], ['3', '#FFD700'], ['4', '#FFCC99'], ['5', '#CCFFE5'], ['6', '#FFFF99'], ['7', '#CCFF99'], ['8', '#CCFFFF'], ['9', '#CCCCFF'], ['10', '#E9967A'], ['11', '#E5CCFF'], ['12', '#DC143C'], ['13', '#FFFFFF'], ['14', '#F0FFF0']], point_color_strategy='map', point_size_by='degree', random_seed=None),
#   'leiden': Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color=None, point_color_by='community', point_color_by_map=[['0', '#4682B4'], ['1', '#FF9999'], ['2', '#4169E1'], ['3', '#FFD700'], ['4', '#FFCC99'], ['5', '#CCFFE5'], ['6', '#FFFF99'], ['7', '#CCFF99'], ['8', '#CCFFFF'], ['9', '#CCCCFF'], ['10', '#E9967A'], ['11', '#E5CCFF'], ['12', '#DC143C'], ['13', '#FFFFFF'], ['14', '#F0FFF0']], point_color_strategy='map', point_size_by='degree', random_seed=None),
#   'dbscan': Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color=None, point_color_by='community', point_color_by_map=[['0', '#4682B4'], ['1', '#FF9999'], ['2', '#4169E1'], ['3', '#FFD700'], ['4', '#FFCC99'], ['5', '#CCFFE5'], ['6', '#FFFF99'], ['7', '#CCFF99'], ['8', '#CCFFFF'], ['9', '#CCCCFF'], ['10', '#E9967A'], ['11', '#E5CCFF'], ['12', '#DC143C'], ['13', '#FFFFFF'], ['14', '#F0FFF0']], point_color_strategy='map', point_size_by='degree', random_seed=None),
#   'spectral': Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color=None, point_color_by='community', point_color_by_map=[['0', '#4682B4'], ['1', '#FF9999'], ['2', '#4169E1'], ['3', '#FFD700'], ['4', '#FFCC99'], ['5', '#CCFFE5'], ['6', '#FFFF99'], ['7', '#CCFF99'], ['8', '#CCFFFF'], ['9', '#CCCCFF'], ['10', '#E9967A'], ['11', '#E5CCFF'], ['12', '#DC143C'], ['13', '#FFFFFF'], ['14', '#F0FFF0']], point_color_strategy='map', point_size_by='degree', random_seed=None)},
#  0.5: {'louvain': Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color=None, point_color_by='community', point_color_by_map=[['0', '#4682B4'], ['1', '#FF9999'], ['2', '#4169E1'], ['3', '#FFD700'], ['4', '#FFCC99'], ['5', '#CCFFE5'], ['6', '#FFFF99'], ['7', '#CCFF99'], ['8', '#CCFFFF'], ['9', '#CCCCFF'], ['10', '#E9967A'], ['11', '#E5CCFF'], ['12', '#DC143C'], ['13', '#FFFFFF'], ['14', '#F0FFF0']], point_color_strategy='map', point_size_by='degree', random_seed=None),
#   'leiden': Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color=None, point_color_by='community', point_color_by_map=[['0', '#4682B4'], ['1', '#FF9999'], ['2', '#4169E1'], ['3', '#FFD700'], ['4', '#FFCC99'], ['5', '#CCFFE5'], ['6', '#FFFF99'], ['7', '#CCFF99'], ['8', '#CCFFFF'], ['9', '#CCCCFF'], ['10', '#E9967A'], ['11', '#E5CCFF'], ['12', '#DC143C'], ['13', '#FFFFFF'], ['14', '#F0FFF0']], point_color_strategy='map', point_size_by='degree', random_seed=None),
#   'dbscan': Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color=None, point_color_by='community', point_color_by_map=[['0', '#4682B4'], ['1', '#FF9999'], ['2', '#4169E1'], ['3', '#FFD700'], ['4', '#FFCC99'], ['5', '#CCFFE5'], ['6', '#FFFF99'], ['7', '#CCFF99'], ['8', '#CCFFFF'], ['9', '#CCCCFF'], ['10', '#E9967A'], ['11', '#E5CCFF'], ['12', '#DC143C'], ['13', '#FFFFFF'], ['14', '#F0FFF0']], point_color_strategy='map', point_size_by='degree', random_seed=None),
#   'spectral': Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_color='#E3E3E3', link_greyout_opacity=0.1, link_source_by='source', link_target_by='target', link_width_by='weight', point_color=None, point_color_by='community', point_color_by_map=[['0', '#4682B4'], ['1', '#FF9999'], ['2', '#4169E1'], ['3', '#FFD700'], ['4', '#FFCC99'], ['5', '#CCFFE5'], ['6', '#FFFF99'], ['7', '#CCFF99'], ['8', '#CCFFFF'], ['9', '#CCCCFF'], ['10', '#E9967A'], ['11', '#E5CCFF'], ['12', '#DC143C'], ['13', '#FFFFFF'], ['14', '#F0FFF0']], point_color_strategy='map', point_size_by='degree', random_seed=None)}}

# %%
widget_cluster_dict[rho]['louvain']
# Out:
# Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_colo…

# %%
widget_cluster_dict[rho]['leiden']
# Out:
# Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_colo…

# %%
widget_cluster_dict[rho]['spectral']
# Out:
# Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_colo…

# %%
widget_cluster_dict[rho]['dbscan']
# Out:
# Cosmograph(background_color='#FFFFFF', focused_point_ring_color=None, hovered_point_ring_color=None, link_colo…
