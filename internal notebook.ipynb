# %%
from workflow.internal import *

# Load dataset (the user will pass the name)
Y, name, dimension, account_prop, trans_matrix = load_dataset()

# Extract time series
extract_timeseries(Y, name)

# Normalise time series
Y_new = normalization(Y, name)

# Print transaction matrix matrix
# print_transaction_matrix(trans_matrix)

# Run SQUIC_fit
W_matrices, _ = squic_fit_computation(Y_new, name, dimension, trans_matrix, printMatrix=True)
# Out:
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    2.763964e+01
#  Y:         111 x 364
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      9.000000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=2.69e+00 time=1.14e-03
# * iter=1 time=2.64e-03 obj=1.82e+02 |delta(obj)|/obj=3.91e-01 nnz(X,L,W)/p=[2.69e+00 1.95e+00 1.07e+00] lns_iter=2
# * iter=2 time=1.24e-03 obj=1.82e+02 |delta(obj)|/obj=0.00e+00 nnz(X,L,W)/p=[2.69e+00 1.95e+00 4.32e+00] lns_iter=1
# #SQUIC Finished: time=5.28e-03 nnz(X,W)/p=[2.69e+00 4.32e+00]
#
# required time: 0.02
# nnz = 188 per rows = 1.69
#  Matrix is symmetric per rho 0.9
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    2.763964e+01
#  Y:         111 x 364
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      5.000000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=2.41e+01 time=4.98e-04
# * iter=1 time=5.37e-03 obj=1.57e+02 |delta(obj)|/obj=2.95e-01 nnz(X,L,W)/p=[2.41e+01 2.66e+01 1.00e+00] lns_iter=5
# * iter=2 time=3.26e-03 obj=1.54e+02 |delta(obj)|/obj=2.15e-02 nnz(X,L,W)/p=[2.41e+01 2.66e+01 4.14e+01] lns_iter=6
# * iter=3 time=5.62e-03 obj=1.49e+02 |delta(obj)|/obj=3.38e-02 nnz(X,L,W)/p=[2.41e+01 2.66e+01 9.07e+01] lns_iter=3
# * iter=4 time=6.45e-03 obj=1.47e+02 |delta(obj)|/obj=1.67e-02 nnz(X,L,W)/p=[2.41e+01 2.66e+01 9.73e+01] lns_iter=1
# * iter=5 time=4.22e-03 obj=1.46e+02 |delta(obj)|/obj=3.65e-03 nnz(X,L,W)/p=[2.42e+01 2.69e+01 9.76e+01] lns_iter=1
# * iter=6 time=5.77e-03 obj=1.46e+02 |delta(obj)|/obj=6.21e-04 nnz(X,L,W)/p=[2.42e+01 2.69e+01 9.78e+01] lns_iter=1
# #SQUIC Finished: time=3.26e-02 nnz(X,W)/p=[2.42e+01 9.78e+01]
#
# required time: 0.05
# nnz = 1378 per rows = 12.41
#  Matrix is symmetric per rho 0.5
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    2.763964e+01
#  Y:         111 x 364
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      2.000000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=5.71e+01 time=6.45e-04
# * iter=1 time=4.70e-03 obj=1.11e+02 |delta(obj)|/obj=3.02e-03 nnz(X,L,W)/p=[5.71e+01 4.58e+01 1.00e+00] lns_iter=6
# * iter=2 time=4.25e-03 obj=1.06e+02 |delta(obj)|/obj=4.55e-02 nnz(X,L,W)/p=[5.71e+01 4.58e+01 1.10e+02] lns_iter=8
# * iter=3 time=1.76e-02 obj=9.58e+01 |delta(obj)|/obj=1.05e-01 nnz(X,L,W)/p=[5.72e+01 4.58e+01 1.11e+02] lns_iter=4
# * iter=4 time=1.73e-02 obj=8.90e+01 |delta(obj)|/obj=7.64e-02 nnz(X,L,W)/p=[5.80e+01 4.73e+01 1.11e+02] lns_iter=2
# * iter=5 time=2.77e-02 obj=8.63e+01 |delta(obj)|/obj=3.12e-02 nnz(X,L,W)/p=[8.03e+01 4.89e+01 1.11e+02] lns_iter=1
# * iter=6 time=3.32e-02 obj=8.38e+01 |delta(obj)|/obj=2.98e-02 nnz(X,L,W)/p=[8.03e+01 4.89e+01 1.11e+02] lns_iter=1
# * iter=7 time=2.75e-02 obj=8.22e+01 |delta(obj)|/obj=2.02e-02 nnz(X,L,W)/p=[8.03e+01 4.89e+01 1.11e+02] lns_iter=1
# * iter=8 time=1.73e-02 obj=8.10e+01 |delta(obj)|/obj=1.43e-02 nnz(X,L,W)/p=[8.04e+01 4.89e+01 1.11e+02] lns_iter=1
# * iter=9 time=1.48e-02 obj=8.03e+01 |delta(obj)|/obj=8.94e-03 nnz(X,L,W)/p=[8.04e+01 4.89e+01 1.11e+02] lns_iter=1
# * iter=10 time=1.21e-02 obj=8.01e+01 |delta(obj)|/obj=2.98e-03 nnz(X,L,W)/p=[8.04e+01 4.89e+01 1.11e+02] lns_iter=1
# * iter=11 time=1.20e-02 obj=8.00e+01 |delta(obj)|/obj=8.52e-04 nnz(X,L,W)/p=[8.04e+01 4.89e+01 1.11e+02] lns_iter=1
# #SQUIC Finished: time=1.90e-01 nnz(X,W)/p=[8.04e+01 1.11e+02]
#
# required time: 0.21
# nnz = 1582 per rows = 14.25
#  Matrix is symmetric per rho 0.2
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    2.763964e+01
#  Y:         111 x 364
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      1.000000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=6.98e+01 time=5.36e-04
# * iter=1 time=2.41e-03 obj=8.73e+01 |delta(obj)|/obj=2.72e-01 nnz(X,L,W)/p=[6.98e+01 4.97e+01 9.49e+00] lns_iter=6
# * iter=2 time=4.94e-03 obj=8.16e+01 |delta(obj)|/obj=6.89e-02 nnz(X,L,W)/p=[6.98e+01 4.97e+01 1.10e+02] lns_iter=7
# * iter=3 time=3.09e-02 obj=7.23e+01 |delta(obj)|/obj=1.30e-01 nnz(X,L,W)/p=[7.85e+01 5.04e+01 1.11e+02] lns_iter=4
# * iter=4 time=2.65e-02 obj=5.89e+01 |delta(obj)|/obj=2.26e-01 nnz(X,L,W)/p=[7.86e+01 5.04e+01 1.11e+02] lns_iter=2
# * iter=5 time=2.78e-02 obj=5.17e+01 |delta(obj)|/obj=1.41e-01 nnz(X,L,W)/p=[8.19e+01 4.89e+01 1.10e+02] lns_iter=1
# * iter=6 time=2.69e-02 obj=4.39e+01 |delta(obj)|/obj=1.76e-01 nnz(X,L,W)/p=[8.19e+01 4.91e+01 1.11e+02] lns_iter=1
# * iter=7 time=1.76e-02 obj=3.89e+01 |delta(obj)|/obj=1.28e-01 nnz(X,L,W)/p=[8.20e+01 4.91e+01 1.11e+02] lns_iter=1
# * iter=8 time=1.45e-02 obj=3.65e+01 |delta(obj)|/obj=6.59e-02 nnz(X,L,W)/p=[8.20e+01 4.91e+01 1.11e+02] lns_iter=1
# * iter=9 time=1.68e-02 obj=3.50e+01 |delta(obj)|/obj=4.52e-02 nnz(X,L,W)/p=[8.20e+01 4.91e+01 1.11e+02] lns_iter=1
# * iter=10 time=1.54e-02 obj=3.41e+01 |delta(obj)|/obj=2.39e-02 nnz(X,L,W)/p=[8.20e+01 4.91e+01 1.11e+02] lns_iter=1
# * iter=11 time=1.52e-02 obj=3.37e+01 |delta(obj)|/obj=1.37e-02 nnz(X,L,W)/p=[8.20e+01 4.91e+01 1.11e+02] lns_iter=1
# * iter=12 time=1.75e-02 obj=3.34e+01 |delta(obj)|/obj=9.19e-03 nnz(X,L,W)/p=[8.20e+01 4.91e+01 1.11e+02] lns_iter=1
# * iter=13 time=1.71e-02 obj=3.32e+01 |delta(obj)|/obj=5.22e-03 nnz(X,L,W)/p=[8.20e+01 4.91e+01 1.11e+02] lns_iter=1
# * iter=14 time=1.64e-02 obj=3.31e+01 |delta(obj)|/obj=3.08e-03 nnz(X,L,W)/p=[8.20e+01 4.91e+01 1.11e+02] lns_iter=1
# * iter=15 time=3.08e-02 obj=3.30e+01 |delta(obj)|/obj=2.41e-03 nnz(X,L,W)/p=[8.20e+01 4.91e+01 1.11e+02] lns_iter=1
# * iter=16 time=1.87e-02 obj=3.30e+01 |delta(obj)|/obj=1.58e-03 nnz(X,L,W)/p=[8.20e+01 4.91e+01 1.11e+02] lns_iter=1
# * iter=17 time=1.86e-02 obj=3.29e+01 |delta(obj)|/obj=1.07e-03 nnz(X,L,W)/p=[8.20e+01 4.91e+01 1.11e+02] lns_iter=1
# * iter=18 time=2.11e-02 obj=3.29e+01 |delta(obj)|/obj=8.57e-04 nnz(X,L,W)/p=[8.20e+01 4.91e+01 1.11e+02] lns_iter=1
# #SQUIC Finished: time=3.41e-01 nnz(X,W)/p=[8.20e+01 1.11e+02]
#
# required time: 0.36
# nnz = 1694 per rows = 15.26
#  Matrix is symmetric per rho 0.1
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    2.763964e+01
#  Y:         111 x 364
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      9.000000e-02
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=7.10e+01 time=5.64e-04
# * iter=1 time=2.52e-03 obj=8.47e+01 |delta(obj)|/obj=3.10e-01 nnz(X,L,W)/p=[7.10e+01 4.96e+01 1.36e+01] lns_iter=6
# * iter=2 time=5.19e-03 obj=7.95e+01 |delta(obj)|/obj=6.59e-02 nnz(X,L,W)/p=[7.10e+01 4.96e+01 1.10e+02] lns_iter=7
# * iter=3 time=2.66e-02 obj=6.85e+01 |delta(obj)|/obj=1.60e-01 nnz(X,L,W)/p=[7.68e+01 5.03e+01 1.11e+02] lns_iter=4
# * iter=4 time=2.57e-02 obj=5.28e+01 |delta(obj)|/obj=2.97e-01 nnz(X,L,W)/p=[7.69e+01 5.04e+01 1.11e+02] lns_iter=2
# * iter=5 time=2.65e-02 obj=4.44e+01 |delta(obj)|/obj=1.90e-01 nnz(X,L,W)/p=[7.94e+01 4.88e+01 1.10e+02] lns_iter=1
# * iter=6 time=2.32e-02 obj=3.69e+01 |delta(obj)|/obj=2.03e-01 nnz(X,L,W)/p=[7.95e+01 4.88e+01 1.11e+02] lns_iter=1
# * iter=7 time=1.72e-02 obj=3.22e+01 |delta(obj)|/obj=1.47e-01 nnz(X,L,W)/p=[7.95e+01 4.88e+01 1.11e+02] lns_iter=1
# * iter=8 time=1.57e-02 obj=2.97e+01 |delta(obj)|/obj=8.13e-02 nnz(X,L,W)/p=[7.95e+01 4.88e+01 1.11e+02] lns_iter=1
# * iter=9 time=1.68e-02 obj=2.83e+01 |delta(obj)|/obj=5.17e-02 nnz(X,L,W)/p=[7.96e+01 4.88e+01 1.11e+02] lns_iter=1
# * iter=10 time=1.61e-02 obj=2.75e+01 |delta(obj)|/obj=2.80e-02 nnz(X,L,W)/p=[7.96e+01 4.88e+01 1.11e+02] lns_iter=1
# * iter=11 time=1.51e-02 obj=2.70e+01 |delta(obj)|/obj=1.74e-02 nnz(X,L,W)/p=[7.96e+01 4.88e+01 1.11e+02] lns_iter=1
# * iter=12 time=1.97e-02 obj=2.67e+01 |delta(obj)|/obj=1.37e-02 nnz(X,L,W)/p=[7.96e+01 4.88e+01 1.11e+02] lns_iter=1
# * iter=13 time=1.73e-02 obj=2.65e+01 |delta(obj)|/obj=7.82e-03 nnz(X,L,W)/p=[7.96e+01 4.88e+01 1.11e+02] lns_iter=1
# * iter=14 time=1.71e-02 obj=2.63e+01 |delta(obj)|/obj=5.16e-03 nnz(X,L,W)/p=[7.96e+01 4.88e+01 1.11e+02] lns_iter=1
# * iter=15 time=1.98e-02 obj=2.62e+01 |delta(obj)|/obj=4.13e-03 nnz(X,L,W)/p=[7.96e+01 4.88e+01 1.11e+02] lns_iter=1
# * iter=16 time=1.89e-02 obj=2.62e+01 |delta(obj)|/obj=2.64e-03 nnz(X,L,W)/p=[7.96e+01 4.88e+01 1.11e+02] lns_iter=1
# * iter=17 time=1.90e-02 obj=2.61e+01 |delta(obj)|/obj=1.85e-03 nnz(X,L,W)/p=[7.96e+01 4.88e+01 1.11e+02] lns_iter=1
# * iter=18 time=2.17e-02 obj=2.61e+01 |delta(obj)|/obj=1.52e-03 nnz(X,L,W)/p=[7.96e+01 4.88e+01 1.11e+02] lns_iter=1
# * iter=19 time=2.08e-02 obj=2.60e+01 |delta(obj)|/obj=1.07e-03 nnz(X,L,W)/p=[7.96e+01 4.88e+01 1.11e+02] lns_iter=1
# * iter=20 time=2.23e-02 obj=2.60e+01 |delta(obj)|/obj=8.76e-04 nnz(X,L,W)/p=[7.96e+01 4.88e+01 1.11e+02] lns_iter=1
# #SQUIC Finished: time=3.69e-01 nnz(X,W)/p=[7.96e+01 1.11e+02]
#
# required time: 0.39
# nnz = 1732 per rows = 15.6
#  Matrix is symmetric per rho 0.09
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    2.763964e+01
#  Y:         111 x 364
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      5.000000e-02
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=7
-03 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=36 time=4.36e-02 obj=-1.12e+01 |delta(obj)|/obj=1.15e-03 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=37 time=4.37e-02 obj=-1.12e+01 |delta(obj)|/obj=1.03e-03 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=38 time=4.36e-02 obj=-1.12e+01 |delta(obj)|/obj=9.04e-04 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# #SQUIC Finished: time=1.18e+00 nnz(X,W)/p=[8.33e+01 1.11e+02]
#
# required time: 1.2
# nnz = 1986 per rows = 17.89
#  Matrix is symmetric per rho 0.05
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    2.763964e+01
#  Y:         111 x 364
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      2.000000e-02
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=8.05e+01 time=5.02e-04
# * iter=1 time=2.83e-03 obj=8.85e+01 |delta(obj)|/obj=2.54e-01 nnz(X,L,W)/p=[8.05e+01 4.94e+01 1.00e+00] lns_iter=7
# * iter=2 time=4.44e-03 obj=6.82e+01 |delta(obj)|/obj=2.98e-01 nnz(X,L,W)/p=[8.05e+01 4.94e+01 1.10e+02] lns_iter=7
# * iter=3 time=2.91e-02 obj=5.61e+01 |delta(obj)|/obj=2.15e-01 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=4
# * iter=4 time=2.88e-02 obj=4.64e+01 |delta(obj)|/obj=2.09e-01 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=3
# * iter=5 time=2.83e-02 obj=2.97e+01 |delta(obj)|/obj=5.60e-01 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=6 time=4.16e-02 obj=2.17e+01 |delta(obj)|/obj=3.68e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=7 time=4.14e-02 obj=1.11e+01 |delta(obj)|/obj=9.59e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.10e+02] lns_iter=1
# * iter=8 time=4.15e-02 obj=-1.29e+00 |delta(obj)|/obj=9.59e+00 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.09e+02] lns_iter=1
# * iter=9 time=5.37e-02 obj=-1.60e+01 |delta(obj)|/obj=9.19e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 9.57e+01] lns_iter=1
# * iter=10 time=4.90e-02 obj=-1.60e+01 |delta(obj)|/obj=9.19e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=14
# * iter=11 time=5.50e-02 obj=-1.65e+01 |delta(obj)|/obj=3.20e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.10e+02] lns_iter=1
# * iter=12 time=6.71e-02 obj=-2.75e+01 |delta(obj)|/obj=3.98e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=13 time=6.36e-02 obj=-3.47e+01 |delta(obj)|/obj=2.09e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.10e+02] lns_iter=1
# * iter=14 time=6.01e-02 obj=-3.98e+01 |delta(obj)|/obj=1.28e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.10e+02] lns_iter=1
# * iter=15 time=6.26e-02 obj=-4.50e+01 |delta(obj)|/obj=1.15e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=16 time=6.70e-02 obj=-4.83e+01 |delta(obj)|/obj=6.80e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=17 time=5.70e-02 obj=-5.08e+01 |delta(obj)|/obj=4.95e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=18 time=6.32e-02 obj=-5.30e+01 |delta(obj)|/obj=4.16e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=19 time=6.14e-02 obj=-5.45e+01 |delta(obj)|/obj=2.89e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=20 time=5.63e-02 obj=-5.58e+01 |delta(obj)|/obj=2.17e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=21 time=5.83e-02 obj=-5.68e+01 |delta(obj)|/obj=1.87e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=22 time=6.76e-02 obj=-5.77e+01 |delta(obj)|/obj=1.56e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=23 time=5.44e-02 obj=-5.84e+01 |delta(obj)|/obj=1.15e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=24 time=6.49e-02 obj=-5.90e+01 |delta(obj)|/obj=1.09e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=25 time=5.69e-02 obj=-5.96e+01 |delta(obj)|/obj=8.68e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=26 time=5.47e-02 obj=-6.00e+01 |delta(obj)|/obj=6.82e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=27 time=6.11e-02 obj=-6.04e+01 |delta(obj)|/obj=6.78e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=28 time=5.73e-02 obj=-6.07e+01 |delta(obj)|/obj=5.63e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=29 time=5.69e-02 obj=-6.10e+01 |delta(obj)|/obj=4.75e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=30 time=6.11e-02 obj=-6.13e+01 |delta(obj)|/obj=4.44e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=31 time=6.20e-02 obj=-6.15e+01 |delta(obj)|/obj=3.92e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=32 time=5.80e-02 obj=-6.17e+01 |delta(obj)|/obj=3.23e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=33 time=6.16e-02 obj=-6.19e+01 |delta(obj)|/obj=3.10e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=34 time=6.30e-02 obj=-6.21e+01 |delta(obj)|/obj=2.70e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=35 time=6.07e-02 obj=-6.22e+01 |delta(obj)|/obj=2.38e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=36 time=6.59e-02 obj=-6.24e+01 |delta(obj)|/obj=2.26e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=37 time=6.52e-02 obj=-6.25e+01 |delta(obj)|/obj=2.00e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=38 time=6.83e-02 obj=-6.26e+01 |delta(obj)|/obj=1.79e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=39 time=6.74e-02 obj=-6.27e+01 |delta(obj)|/obj=1.66e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=40 time=6.61e-02 obj=-6.28e+01 |delta(obj)|/obj=1.50e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=41 time=6.59e-02 obj=-6.29e+01 |delta(obj)|/obj=1.34e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=42 time=6.98e-02 obj=-6.30e+01 |delta(obj)|/obj=1.30e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=43 time=7.05e-02 obj=-6.30e+01 |delta(obj)|/obj=1.17e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=44 time=6.90e-02 obj=-6.31e+01 |delta(obj)|/obj=1.04e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=45 time=7.26e-02 obj=-6.32e+01 |delta(obj)|/obj=1.01e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=46 time=7.21e-02 obj=-6.32e+01 |delta(obj)|/obj=9.11e-04 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# #SQUIC Finished: time=2.59e+00 nnz(X,W)/p=[8.34e+01 1.11e+02]
#
# required time: 2.61
# nnz = 2558 per rows = 23.05
#  Matrix is symmetric per rho 0.02
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    2.763964e+01
#  Y:         111 x 364
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      1.000000e-02
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=8.15e+01 time=7.05e-04
# * iter=1 time=2.73e-03 obj=8.64e+01 |delta(obj)|/obj=2.85e-01 nnz(X,L,W)/p=[8.15e+01 4.92e+01 1.00e+00] lns_iter=7
# * iter=2 time=5.32e-03 obj=7.42e+01 |delta(obj)|/obj=1.64e-01 nnz(X,L,W)/p=[8.15e+01 4.92e+01 9.79e+01] lns_iter=8
# * iter=3 time=2.72e-02 obj=5.45e+01 |delta(obj)|/obj=3.62e-01 nnz(X,L,W)/p=[8.22e+01 4.92e+01 1.10e+02] lns_iter=5
# * iter=4 time=2.88e-02 obj=2.93e+01 |delta(obj)|/obj=8.62e-01 nnz(X,L,W)/p=[8.28e+01 4.92e+01 1.11e+02] lns_iter=3
# * iter=5 time=2.87e-02 obj=1.69e+01 |delta(obj)|/obj=7.31e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.10e+02] lns_iter=1
# * iter=6 time=4.16e-02 obj=4.40e+00 |delta(obj)|/obj=2.84e+00 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.10e+02] lns_iter=1
# * iter=7 time=4.15e-02 obj=-6.87e+00 |delta(obj)|/obj=1.64e+00 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.08e+02] lns_iter=1
# * iter=8 time=4.15e-02 obj=-1.87e+01 |delta(obj)|/obj=6.32e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.08e+02] lns_iter=1
# * iter=9 time=5.38e-02 obj=-3.38e+01 |delta(obj)|/obj=4.49e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.10e+02] lns_iter=1
# * iter=10 time=5.45e-02 obj=-4.17e+01 |delta(obj)|/obj=1.87e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.10e+02] lns_iter=1
# * iter=11 time=5.31e-02 obj=-4.98e+01 |delta(obj)|/obj=1.64e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=12 time=6.58e-02 obj=-5.68e+01 |delta(obj)|/obj=1.23e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=13 time=6.34e-02 obj=-6.25e+01 |delta(obj)|/obj=9.05e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=14 time=6.40e-02 obj=-6.64e+01 |delta(obj)|/obj=5.95e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=15 time
-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=54 time=1.20e-01 obj=-9.66e+01 |delta(obj)|/obj=1.12e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=55 time=1.19e-01 obj=-9.67e+01 |delta(obj)|/obj=1.06e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=56 time=1.44e-01 obj=-9.68e+01 |delta(obj)|/obj=1.01e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=57 time=1.24e-01 obj=-9.69e+01 |delta(obj)|/obj=9.57e-04 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# #SQUIC Finished: time=4.91e+00 nnz(X,W)/p=[8.34e+01 1.11e+02]
#
# required time: 4.94
# nnz = 3062 per rows = 27.59
#  Matrix is symmetric per rho 0.01

# %%
# Use the extracted W for clustering
dict_cluster = clustering(W_matrices)

# Report internal metrics on the clustering
int_metrics = internal_metrics(dict_cluster, W_matrices)
# Out:
# Trying different params for DBSCAN for lambda = 0.9
# 100%|██████████| 20/20 [00:00<00:00, 145.81it/s]
# /opt/anaconda3/envs/bank/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# Number of louvain cluster for rho 0.9 is 87
# Number of DBSCAN cluster for rho 0.9 is 88
# Number of Spectral cluster for rho 0.9 is 87
#
# Time for Louvain for lambda = 0.9 -> 0.0033228397369384766
# Time for DBSCAN for lambda = 0.9 -> 0.18810486793518066
# Time for Spectral for lambda = 0.9 -> 0.03140091896057129
#
# Trying different params for DBSCAN for lambda = 0.5
# 100%|██████████| 20/20 [00:00<00:00, 130.54it/s]
# Number of louvain cluster for rho 0.5 is 13
# Number of DBSCAN cluster for rho 0.5 is 13
# Number of Spectral cluster for rho 0.5 is 13
#
# Time for Louvain for lambda = 0.5 -> 0.005949974060058594
# Time for DBSCAN for lambda = 0.5 -> 0.15642690658569336
# Time for Spectral for lambda = 0.5 -> 0.0034711360931396484
#
# Trying different params for DBSCAN for lambda = 0.2
# 100%|██████████| 20/20 [00:00<00:00, 125.50it/s]
# Number of louvain cluster for rho 0.2 is 9
# Number of DBSCAN cluster for rho 0.2 is 9
# Number of Spectral cluster for rho 0.2 is 9
#
# Time for Louvain for lambda = 0.2 -> 0.006833314895629883
# Time for DBSCAN for lambda = 0.2 -> 0.16246795654296875
# Time for Spectral for lambda = 0.2 -> 0.0030488967895507812
#
# Trying different params for DBSCAN for lambda = 0.1
# 100%|██████████| 20/20 [00:00<00:00, 122.31it/s]
# Number of louvain cluster for rho 0.1 is 7
# Number of DBSCAN cluster for rho 0.1 is 7
# Number of Spectral cluster for rho 0.1 is 7
#
# Time for Louvain for lambda = 0.1 -> 0.007923126220703125
# Time for DBSCAN for lambda = 0.1 -> 0.16634702682495117
# Time for Spectral for lambda = 0.1 -> 0.0035216808319091797
#
# Trying different params for DBSCAN for lambda = 0.09
# 100%|██████████| 20/20 [00:00<00:00, 111.34it/s]
# Number of louvain cluster for rho 0.09 is 6
# Number of DBSCAN cluster for rho 0.09 is 6
# Number of Spectral cluster for rho 0.09 is 6
#
# Time for Louvain for lambda = 0.09 -> 0.008185148239135742
# Time for DBSCAN for lambda = 0.09 -> 0.18235015869140625
# Time for Spectral for lambda = 0.09 -> 0.003153085708618164
#
# Trying different params for DBSCAN for lambda = 0.05
# 100%|██████████| 20/20 [00:00<00:00, 119.39it/s]
# Number of louvain cluster for rho 0.05 is 6
# Number of DBSCAN cluster for rho 0.05 is 5
# Number of Spectral cluster for rho 0.05 is 6
#
# Time for Louvain for lambda = 0.05 -> 0.008763790130615234
# Time for DBSCAN for lambda = 0.05 -> 0.17084598541259766
# Time for Spectral for lambda = 0.05 -> 0.0030579566955566406
# Trying different params for DBSCAN for lambda = 0.02
# 100%|██████████| 20/20 [00:00<00:00, 114.23it/s]
# Number of louvain cluster for rho 0.02 is 5
# Number of DBSCAN cluster for rho 0.02 is 5
# Number of Spectral cluster for rho 0.02 is 5
#
# Time for Louvain for lambda = 0.02 -> 0.009247064590454102
# Time for DBSCAN for lambda = 0.02 -> 0.17787480354309082
# Time for Spectral for lambda = 0.02 -> 0.0031480789184570312
# Trying different params for DBSCAN for lambda = 0.01
# 100%|██████████| 20/20 [00:00<00:00, 109.11it/s]
# Number of louvain cluster for rho 0.01 is 6
# Number of DBSCAN cluster for rho 0.01 is 2
# Number of Spectral cluster for rho 0.01 is 6
#
# Time for Louvain for lambda = 0.01 -> 0.012102842330932617
# Time for DBSCAN for lambda = 0.01 -> 0.18625903129577637
# Time for Spectral for lambda = 0.01 -> 0.003039836883544922

# %%
visualize_metrics(int_metrics)
# Out:
# For rho = 0.9
#     louvain : {'ncut': 1.55, 'rcut': 0.29, 'modularity': 0.22, 'CC': 83, 'nCluster': 87}
#     dbscan : {'ncut': 7.01, 'rcut': 0.14, 'modularity': 0.01, 'CC': 83, 'nCluster': 88}
#     spectral : {'ncut': 8.47, 'rcut': 1.73, 'modularity': 0.11, 'CC': 83, 'nCluster': 87}
#
#
# For rho = 0.5
#     louvain : {'ncut': 1.28, 'rcut': 0.82, 'modularity': 0.45, 'CC': 10, 'nCluster': 13}
#     dbscan : {'ncut': 4.0, 'rcut': 0.21, 'modularity': 0.0, 'CC': 10, 'nCluster': 13}
#     spectral : {'ncut': 6.39, 'rcut': 2.53, 'modularity': 0.4, 'CC': 10, 'nCluster': 13}
#
#
# For rho = 0.2
#     louvain : {'ncut': 1.78, 'rcut': 2.93, 'modularity': 0.46, 'CC': 4, 'nCluster': 9}
#     dbscan : {'ncut': 5.0, 'rcut': 0.82, 'modularity': 0.01, 'CC': 4, 'nCluster': 9}
#     spectral : {'ncut': 3.61, 'rcut': 4.66, 'modularity': 0.42, 'CC': 4, 'nCluster': 9}
#
#
# For rho = 0.1
#     louvain : {'ncut': 2.8, 'rcut': 7.28, 'modularity': 0.42, 'CC': 1, 'nCluster': 7}
#     dbscan : {'ncut': 6.01, 'rcut': 5.18, 'modularity': 0.0, 'CC': 1, 'nCluster': 7}
#     spectral : {'ncut': 2.82, 'rcut': 7.64, 'modularity': 0.41, 'CC': 1, 'nCluster': 7}
#
#
# For rho = 0.09
#     louvain : {'ncut': 2.6, 'rcut': 8.46, 'modularity': 0.4, 'CC': 1, 'nCluster': 6}
#     dbscan : {'ncut': 5.0, 'rcut': 2.5, 'modularity': 0.0, 'CC': 1, 'nCluster': 6}
#     spectral : {'ncut': 2.27, 'rcut': 6.62, 'modularity': 0.41, 'CC': 1, 'nCluster': 6}
#
#
# For rho = 0.05
#     louvain : {'ncut': 2.84, 'rcut': 14.13, 'modularity': 0.37, 'CC': 1, 'nCluster': 6}
#     dbscan : {'ncut': 4.01, 'rcut': 6.83, 'modularity': 0.0, 'CC': 1, 'nCluster': 5}
#     spectral : {'ncut': 2.91, 'rcut': 14.55, 'modularity': 0.35, 'CC': 1, 'nCluster': 6}
#
#
# For rho = 0.02
#     louvain : {'ncut': 2.52, 'rcut': 29.86, 'modularity': 0.3, 'CC': 1, 'nCluster': 5}
#     dbscan : {'ncut': 4.03, 'rcut': 44.22, 'modularity': -0.0, 'CC': 1, 'nCluster': 5}
#     spectral : {'ncut': 2.47, 'rcut': 31.59, 'modularity': 0.29, 'CC': 1, 'nCluster': 5}
#
#
# For rho = 0.01
#     louvain : {'ncut': 3.37, 'rcut': 72.59, 'modularity': 0.27, 'CC': 1, 'nCluster': 6}
#     dbscan : {'ncut': 1.01, 'rcut': 11.51, 'modularity': -0.0, 'CC': 1, 'nCluster': 2}
#     spectral : {'ncut': 3.64, 'rcut': 81.04, 'modularity': 0.22, 'CC': 1, 'nCluster': 6}

# %%
# Visualise with cosmograph
widget_dict = visualize_graph_internal(W_matrices, dict_cluster, account_prop, name)

# %%
rho = 0.5

# %%
widget_dict[rho]['louvain']
# Out:
# Cosmograph(background_color=None, focused_point_ring_color=None, hovered_point_ring_color=None, link_color=Non…

# %%
widget_dict[rho]["spectral"]
# Out:
# Cosmograph(background_color=None, focused_point_ring_color=None, hovered_point_ring_color=None, link_color=Non…

# %%
widget_dict[rho]["dbscan"]
# Out:
# Cosmograph(background_color=None, focused_point_ring_color=None, hovered_point_ring_color=None, link_color=Non…

# %%
lists = extract_results(int_metrics)

# %%
plot_results('ncut', 'N Cut', lists)
plot_results('ncut', 'N Cut', lists, ['louvain', 'spectral'])

# %%
plot_results('rcut', 'Ratio Cut', lists)
plot_results('rcut', 'Ratio Cut', lists, methods=['louvain', 'spectral'])

# %%
plot_results('modularity', 'Modularity', lists)
plot_results('modularity', 'Modularity', lists, methods=['louvain', 'spectral'])

# %%
plot_results('nCluster', 'num Cluster', lists)

# %%
def plot_results_2(metrics, ylabel, results, methods=['louvain', 'spectral', 'dbscan']):
    # Create the plot
    plt.figure(figsize=(6, 6))

    colors = ['steelblue', 'gold', 'indianred']
    dot = ['o-', 's-', '^-']

    if methods == ['louvain', 'spectral']:
        for i, method in enumerate(methods): 
            plt.plot(results['rho_values'], results[f'{method}_{metrics}'], dot[i], label=f'{method}', color=colors[i])
        
        plt.yscale('log')
    
    else:
        plt.plot(results['rho_values'], results[f'louvain_{metrics}'], 'o-', label='Louvain', color=colors[0])
        plt.plot(results['rho_values'], results[f'spectral_{metrics}'], 's-', label='Spectral', color=colors[1])
        plt.plot(results['rho_values'], results[f'dbscan_{metrics}'], '^-', label='DBSCAN', color=colors[2])
    # plt.plot(results['rho_values'], results[f'dbscan_{metrics}'], '^-', color=colors[0])


    plt.xlabel('Reg. Parameter (λ)', fontsize=22)
    plt.ylabel(ylabel, fontsize=22)
    plt.xscale('log')
    plt.yscale('log')
    plt.tick_params(axis='x', labelsize=22)
    plt.tick_params(axis='y', labelsize=22)
    plt.show()

# %%
plot_results_2('CC', 'Connected Components', lists)
