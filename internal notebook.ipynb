# %%
from workflow.internal import *

# Load dataset (the user will pass the name)
Y, name, dimension, account_prop, trans_matrix = load_dataset()

# Extract time series
extract_timeseries(Y, name)

# Normalise time series
if name != 'LIBRA':
    Y = normalization(Y, name)

# Print transaction matrix matrix
print_transaction_matrix(trans_matrix)

# Run SQUIC_fit
A_matrices, _ = squic_fit_computation(Y, name, dimension, trans_matrix, printMatrix=True)
# Out:
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    1.590000e+01
#  Y:         100 x 200
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      9.000000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=2.96e+01 time=5.49e-04
# * iter=1 time=1.32e-03 obj=5.09e+03 |delta(obj)|/obj=9.80e-01 nnz(X,L,W)/p=[2.96e+01 2.21e+01 1.10e+00] lns_iter=3
# * iter=2 time=1.84e-03 obj=4.48e+03 |delta(obj)|/obj=1.37e-01 nnz(X,L,W)/p=[2.96e+01 2.21e+01 5.07e+01] lns_iter=4
# * iter=3 time=7.15e-03 obj=4.22e+03 |delta(obj)|/obj=6.15e-02 nnz(X,L,W)/p=[3.79e+01 2.38e+01 5.35e+01] lns_iter=5
# * iter=4 time=7.29e-03 obj=3.75e+03 |delta(obj)|/obj=1.24e-01 nnz(X,L,W)/p=[3.91e+01 2.41e+01 5.36e+01] lns_iter=4
# * iter=5 time=8.38e-03 obj=3.18e+03 |delta(obj)|/obj=1.80e-01 nnz(X,L,W)/p=[4.41e+01 2.61e+01 5.36e+01] lns_iter=3
# * iter=6 time=1.24e-02 obj=2.76e+03 |delta(obj)|/obj=1.53e-01 nnz(X,L,W)/p=[4.57e+01 2.61e+01 5.36e+01] lns_iter=3
# * iter=7 time=1.23e-02 obj=2.13e+03 |delta(obj)|/obj=2.94e-01 nnz(X,L,W)/p=[4.63e+01 2.68e+01 5.36e+01] lns_iter=2
# * iter=8 time=1.40e-02 obj=1.86e+03 |delta(obj)|/obj=1.49e-01 nnz(X,L,W)/p=[5.02e+01 2.68e+01 5.36e+01] lns_iter=2
# * iter=9 time=1.42e-02 obj=1.73e+03 |delta(obj)|/obj=7.46e-02 nnz(X,L,W)/p=[5.11e+01 2.68e+01 5.36e+01] lns_iter=2
# * iter=10 time=1.86e-02 obj=1.65e+03 |delta(obj)|/obj=4.45e-02 nnz(X,L,W)/p=[5.11e+01 2.68e+01 5.36e+01] lns_iter=2
# * iter=11 time=1.82e-02 obj=1.61e+03 |delta(obj)|/obj=2.67e-02 nnz(X,L,W)/p=[5.11e+01 2.68e+01 5.36e+01] lns_iter=2
# * iter=12 time=2.22e-02 obj=1.58e+03 |delta(obj)|/obj=1.87e-02 nnz(X,L,W)/p=[5.11e+01 2.68e+01 5.36e+01] lns_iter=2
# * iter=13 time=2.18e-02 obj=1.57e+03 |delta(obj)|/obj=1.07e-02 nnz(X,L,W)/p=[5.11e+01 2.68e+01 5.36e+01] lns_iter=2
# * iter=14 time=2.14e-02 obj=1.55e+03 |delta(obj)|/obj=1.29e-02 nnz(X,L,W)/p=[5.11e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=15 time=2.75e-02 obj=1.54e+03 |delta(obj)|/obj=1.84e-03 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=16 time=2.75e-02 obj=1.54e+03 |delta(obj)|/obj=3.81e-03 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=17 time=2.56e-02 obj=1.52e+03 |delta(obj)|/obj=9.85e-03 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=18 time=2.91e-02 obj=1.50e+03 |delta(obj)|/obj=1.54e-02 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=19 time=3.14e-02 obj=1.49e+03 |delta(obj)|/obj=2.70e-03 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=20 time=2.98e-02 obj=1.48e+03 |delta(obj)|/obj=7.78e-03 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=21 time=3.28e-02 obj=1.46e+03 |delta(obj)|/obj=1.54e-02 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=22 time=3.55e-02 obj=1.46e+03 |delta(obj)|/obj=3.27e-03 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=23 time=3.37e-02 obj=1.44e+03 |delta(obj)|/obj=9.23e-03 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=24 time=3.69e-02 obj=1.42e+03 |delta(obj)|/obj=1.49e-02 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=25 time=3.82e-02 obj=1.41e+03 |delta(obj)|/obj=5.97e-03 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=26 time=3.66e-02 obj=1.39e+03 |delta(obj)|/obj=1.44e-02 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=27 time=4.19e-02 obj=1.38e+03 |delta(obj)|/obj=7.85e-03 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=28 time=4.04e-02 obj=1.36e+03 |delta(obj)|/obj=1.52e-02 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=29 time=4.23e-02 obj=1.35e+03 |delta(obj)|/obj=5.23e-03 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=30 time=4.39e-02 obj=1.34e+03 |delta(obj)|/obj=1.43e-02 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=31 time=4.60e-02 obj=1.33e+03 |delta(obj)|/obj=6.86e-03 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=32 time=4.39e-02 obj=1.31e+03 |delta(obj)|/obj=1.46e-02 nnz(X,L,W)/p=[5.19e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=33 time=5.23e-02 obj=1.30e+03 |delta(obj)|/obj=2.46e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=34 time=4.95e-02 obj=1.29e+03 |delta(obj)|/obj=7.29e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=35 time=4.76e-02 obj=1.27e+03 |delta(obj)|/obj=1.53e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=36 time=5.41e-02 obj=1.27e+03 |delta(obj)|/obj=5.52e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=37 time=5.18e-02 obj=1.25e+03 |delta(obj)|/obj=1.38e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=38 time=5.28e-02 obj=1.24e+03 |delta(obj)|/obj=9.76e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=39 time=5.47e-02 obj=1.22e+03 |delta(obj)|/obj=1.52e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=40 time=6.03e-02 obj=1.22e+03 |delta(obj)|/obj=2.47e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=41 time=5.72e-02 obj=1.21e+03 |delta(obj)|/obj=7.22e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=42 time=7.05e-02 obj=1.19e+03 |delta(obj)|/obj=1.60e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=43 time=6.20e-02 obj=1.18e+03 |delta(obj)|/obj=5.46e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=44 time=5.87e-02 obj=1.17e+03 |delta(obj)|/obj=1.36e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=45 time=6.34e-02 obj=1.15e+03 |delta(obj)|/obj=1.11e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=46 time=6.21e-02 obj=1.14e+03 |delta(obj)|/obj=1.39e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=47 time=6.36e-02 obj=1.13e+03 |delta(obj)|/obj=8.74e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=48 time=6.57e-02 obj=1.11e+03 |delta(obj)|/obj=1.56e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=49 time=6.98e-02 obj=1.10e+03 |delta(obj)|/obj=5.44e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=50 time=6.63e-02 obj=1.09e+03 |delta(obj)|/obj=1.34e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=51 time=7.35e-02 obj=1.08e+03 |delta(obj)|/obj=5.99e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=52 time=7.00e-02 obj=1.07e+03 |delta(obj)|/obj=1.24e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=53 time=6.98e-02 obj=1.06e+03 |delta(obj)|/obj=1.32e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=54 time=7.38e-02 obj=1.04e+03 |delta(obj)|/obj=1.26e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=55 time=7.31e-02 obj=1.03e+03 |delta(obj)|/obj=1.24e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=56 time=7.22e-02 obj=1.02e+03 |delta(obj)|/obj=1.35e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=57 time=7.78e-02 obj=1.01e+03 |delta(obj)|/obj=9.77e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=58 time=7.58e-02 obj=9.91e+02 |delta(obj)|/obj=1.56e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=59 time=8.00e-02 obj=9.86e+02 |delta(obj)|/obj=5.60e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=60 time=7.98e-02 obj=9.72e+02 |delta(obj)|/obj=1.38e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=61 time=8.04e-02 obj=9.61e+02 |delta(obj)|/obj=1.22e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=62 time=8.09e-02 obj=9.50e+02 |delta(obj)|/obj=1.10e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=63 time=8.25e-02 obj=9.36e+02 |delta(obj)|/obj=1.49e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=64 time=8.52e-02 obj=9.28e+02 |delta(obj)|/obj=8.71e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=65 time=8.19e-02 obj=9.14e+02 |delta(obj)|/obj=1.55e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=66 time=8.86e-02 obj=9.06e+02 |delta(obj)|/obj=9.31e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=67 time=8.51e-02 obj=8.92e+02 |delta(obj)|/obj=1.56e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=68 time=8.93e-02 obj=8.85e+02 |delta(obj)|/obj=7.42e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=69 time=8.79e-02 obj=8.71e+02 |delta(obj)|/obj=1.58e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=70 time=9.60e-02 obj=8.68e+02 |delta(obj)|/obj=4.10e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=71 time=9.04e-02 obj=8.58e+02 |delta(obj)|/obj=1.11e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=72 time=9.17e-02 obj=8.45e+02 |delta(obj)|/obj=1.58e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=73 time=9.72e-02 obj=8.40e+02 |delta(obj)|/obj=6.15e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=74 time=9.19e-02 obj=8.28e+02 |delta(obj)|/obj=1.42e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=75 time=9.84e-02 obj=8.21e+02 |delta(obj)|/obj=9.16e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=76 time=9.45e-02 obj=8.07e+02 |delta(obj)|/obj=1.70e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=77 time=9.83e-02 obj=8.00e+02 |delta(obj)|/obj=8.37e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=78 time=9.76e-02 obj=7.87e+02 |delta(obj)|/obj=1.69e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=79 time=1.03e-01 obj=7.81e+02 |delta(obj)|/obj=6.91e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=80 time=9.77e-02 obj=7.70e+02 |delta(obj)|/obj=1.54e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=81 time=1.03e-01 obj=7.61e+02 |delta(obj)|/obj=1.06e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=82 time=1.01e-01 obj=7.49e+02 |delta(obj)|/obj=1.63e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=83 time=1.03e-01 obj=7.42e+02 |delta(obj)|/obj=9.86e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=84 time=1.04e-01 obj=7.29e+02 |delta(obj)|/obj=1.75e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=85 time=1.07e-01 obj=7.23e+02 |delta(obj)|/obj=8.98e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=86 time=1.03e-01 obj=7.11e+02 |delta(obj)|/obj=1.68e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=87 time=1.11e-01 obj=7.05e+02 |delta(obj)|/obj=8.14e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=88 time=1.06e-01 obj=6.93e+02 |delta(obj)|/obj=1.70e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=89 time=1.13e-01 obj=6.90e+02 |delta(obj)|/obj=4.88e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=90 time=1.11e-01 obj=6.81e+02 |delta(obj)|/obj=1.30e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=91 time=1.09e-01 obj=6.70e+02 |delta(obj)|/obj=1.63e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=92 time=1.12e-01 obj=6.63e+02 |delta(obj)|/obj=1.05e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=93 time=1.12e-01 obj=6.52e+02 |delta(obj)|/obj=1.75e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=94 time=1.17e-01 obj=6.47e+02 |delta(obj)|/obj=7.87e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=95 time=1.13e-01 obj=6.37e+02 |delta(obj)|/obj=1.57e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=96 time=1.18e-01 obj=6.30e+02 |delta(obj)|/obj=1.11e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=97 time=1.15e-01 obj=6.20e+02 |delta(obj)|/obj=1.61e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=98 time=1.17e-01 obj=6.13e+02 |delta(obj)|/obj=1.17e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=99 time=1.16e-01 obj=6.03e+02 |delta(obj)|/obj=1.62e-02 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# * iter=100 time=1.30e-01 obj=5.99e+02 |delta(obj)|/obj=5.64e-03 nnz(X,L,W)/p=[5.20e+01 2.68e+01 5.36e+01] lns_iter=1
# #SQUIC Finished: time=6.68e+00 nnz(X,W)/p=[5.20e+01 5.36e+01]
#
# required time: 6.68
# nnz = 1430 per rows = 14.3
#  Matrix is symmetric per rho 0.9
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    1.590000e+01
#  Y:         100 x 200
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      5.000000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=6.14e+01 time=3.95e-04
# * iter=1 time=1.96e-03 obj=6.48e+03 |delta(obj)|/obj=9.85e-01 nnz(X,L,W)/p=[6.14e+01 3.93e+01 1.00e+00] lns_iter=6
# * iter=2 time=3.41e-03 obj=6.46e+03 |delta(obj)|/obj=4.20e-03 nnz(X,L,W)/p=[6.14e+01 3.93e+01 7.38e+01] lns_iter=9
# * iter=3 time=1.26e-02 obj=4.87e+03 |delta(obj)|/obj=3.26e-01 nnz(X,L,W)/p=[6.14e+01 3.93e+01 9.85e+01] lns_iter=3
# * iter=4 time=1.45e-02 obj=2.50e+03 |delta(obj)|/obj=9.50e-01 nnz(X,L,W)/p=[6.14e+01 3.93e+01 8.88e+01] lns_iter=2
# * iter=5 time=1.37e-02 obj=1.32e+03 |delta(obj)|/obj=8.97e-01 nnz(X,L,W)/p=[6.14e+01 3.93e+01 8.17e+01] lns_iter=2
# * iter=6 time=1.91e-02 obj=7.31e+02 |delta(obj)|/obj=8.02e-01 nnz(X,L,W)/p=[6.14e+01 3.93e+01 8.16e+01] lns_iter=2
# * iter=7 time=1.95e-02 obj=4.43e+02 |delta(obj)|/obj=6.51e-01 nnz(X,L,W)/p=[6.14e+01 3.93e+01 8.25e+01] lns_iter=2
# * iter=8 time=1.93e-02 obj=3.03e+02 |delta(obj)|/obj=4.59e-01 nnz(X,L,W)/p=[6.14e+01 3.93e+01 8.43e+01] lns_iter=2
# * iter=9 time=2.57e-02 obj=2.39e+02 |delta(obj)|/obj=2.71e-01 nnz(X,L,W)/p=[6.14e+01 3.93e+01 8.45e+01] lns_iter=2
# * iter=10 time=2.54e-02 obj=2.11e+02 |delta(obj)|/obj=1.30e-01 nnz(X,L,W)/p=[6.14e+01 3.93e+01 8.74e+01] lns_iter=2
# * iter=11 time=2.59e-02 obj=2.02e+02 |delta(obj)|/obj=4.59e-02 nnz(X,L,W)/p=[6.14e+01 3.93e+01 8.96e+01] lns_iter=2
# * iter=12 time=3.23e-02 obj=2.00e+02 |delta(obj)|/obj=1.01e-02 nnz(X,L,W)/p=[6.14e+01 3.93e+01 9.49e+01] lns_iter=2
# * iter=13 time=3.28e-02 obj=2.00e+02 |delta(obj)|/obj=4.63e-04 nnz(X,L,W)/p=[6.14e+01 3.93e+01 9.75e+01] lns_iter=1
# #SQUIC Finished: time=2.47e-01 nnz(X,W)/p=[6.14e+01 9.75e+01]
#
# required time: 0.25
# nnz = 2088 per rows = 20.88
#  Matrix is symmetric per rho 0.5
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    1.590000e+01
#  Y:         100 x 200
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      2.000000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=7.47e+01 time=4.65e-04
# * iter=1 time=2.55e-03 obj=6.54e+03 |delta(obj)|/obj=9.85e-01 nnz(X,L,W)/p=[7.47e+01 4.71e+01 1.00e+00] lns_iter=7
# * iter=2 time=4.27e-03 obj=6.51e+03 |delta(obj)|/obj=5.26e-03 nnz(X,L,W)/p=[7.47e+01 4.71e+01 8.63e+01] lns_iter=9
# * iter=3 time=1.71e-02 obj=5.70e+03 |delta(obj)|/obj=1.42e-01 nnz(X,L,W)/p=[7.47e+01 4.71e+01 1.00e+02] lns_iter=4
# * iter=4 time=1.85e-02 obj=2.88e+03 |delta(obj)|/obj=9.79e-01 nnz(X,L,W)/p=[7.48e+01 4.71e+01 9.99e+01] lns_iter=2
# * iter=5 time=1.92e-02 obj=1.48e+03 |delta(obj)|/obj=9.44e-01 nnz(X,L,W)/p=[7.73e+01 4.89e+01 9.81e+01] lns_iter=2
# * iter=6 time=3.00e-02 obj=1.13e+03 |delta(obj)|/obj=3.06e-01 nnz(X,L,W)/p=[7.98e+01 4.90e+01 9.86e+01] lns_iter=3
# * iter=7 time=3.01e-02 obj=8.75e+02 |delta(obj)|/obj=2.96e-01 nnz(X,L,W)/p=[8.02e+01 4.92e+01 9.99e+01] lns_iter=3
# * iter=8 time=3.00e-02 obj=6.89e+02 |delta(obj)|/obj=2.69e-01 nnz(X,L,W)/p=[8.16e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=9 time=3.94e-02 obj=5.52e+02 |delta(obj)|/obj=2.48e-01 nnz(X,L,W)/p=[8.18e+01 5.00e+01 9.99e+01] lns_iter=3
# * iter=10 time=3.96e-02 obj=4.51e+02 |delta(obj)|/obj=2.25e-01 nnz(X,L,W)/p=[8.19e+01 5.00e+01 9.99e+01] lns_iter=3
# * iter=11 time=3.96e-02 obj=3.78e+02 |delta(obj)|/obj=1.95e-01 nnz(X,L,W)/p=[8.19e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=12 time=4.94e-02 obj=3.29e+02 |delta(obj)|/obj=1.49e-01 nnz(X,L,W)/p=[8.25e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=13 time=4.96e-02 obj=2.95e+02 |delta(obj)|/obj=1.16e-01 nnz(X,L,W)/p=[8.25e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=14 time=4.98e-02 obj=2.72e+02 |delta(obj)|/obj=8.21e-02 nnz(X,L,W)/p=[8.27e+01 5.00e+01 9.99e+01] lns_iter=3
# * iter=15 time=5.92e-02 obj=2.57e+02 |delta(obj)|/obj=6.07e-02 nnz(X,L,W)/p=[8.27e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=16 time=5.89e-02 obj=2.36e+02 |delta(obj)|/obj=8.67e-02 nnz(X,L,W)/p=[8.27e+01 5.00e+01 1.00e+02] lns_iter=2
# * iter=17 time=5.98e-02 obj=2.28e+02 |delta(obj)|/obj=3.57e-02 nnz(X,L,W)/p=[8.31e+01 5.00e+01 1.00e+02] lns_iter=2
# * iter=18 time=6.87e-02 obj=2.22e+02 |delta(obj)|/obj=2.90e-02 nnz(X,L,W)/p=[8.31e+01 5.00e+01 1.00e+02] lns_iter=2
# * iter=19 time=6.88e-02 obj=2.12e+02 |delta(obj)|/obj=4.38e-02 nnz(X,L,W)/p=[8.31e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=20 time=7.03e-02 obj=2.09e+02 |delta(obj)|/obj=1.55e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=21 time=7.85e-02 obj=2.03e+02 |delta(obj)|/obj=2.93e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=22 time=7.88e-02 obj=1.98e+02 |delta(obj)|/obj=2.44e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=23 time=7.85e-02 obj=1.93e+02 |delta(obj)|/obj=2.71e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=24 time=8.79e-02 obj=1.88e+02 |delta(obj)|/obj=2.49e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=25 time=8.78e-02 obj=1.83e+02 |delta(obj)|/obj=2.78e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=26 time=8.71e-02 obj=1.79e+02 |delta(obj)|/obj=2.57e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=27 time=9.41e-02 obj=1.74e+02 |delta(obj)|/obj=2.92e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=28 time=9.16e-02 obj=1.69e+02 |delta(obj)|/obj=2.55e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 9.98e+01] lns_iter=1
# * iter=29 time=9.64e-02 obj=1.65e+02 |delta(obj)|/obj=2.81e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=30 time=8.36e-02 obj=1.60e+02 |delta(obj)|/obj=2.57e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=31 time=7.93e-02 obj=1.57e+02 |delta(obj)|/obj=2.26e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=32 time=6.70e-02 obj=1.54e+02 |delta(obj)|/obj=2.14e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=33 time=6.73e-02 obj=1.51e+02 |delta(obj)|/obj=2.02e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=34 time=6.51e-02 obj=1.48e+02 |delta(obj)|/obj=1.93e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=35 time=6.15e-02 obj=1.45e+02 |delta(obj)|/obj=1.83e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=36 time=6.13e-02 obj=1.43e+02 |delta(obj)|/obj=1.68e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=37 time=5.98e-02 obj=1.41e+02 |delta(obj)|/obj=1.30e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=38 time=5.80e-02 obj=1.39e+02 |delta(obj)|/obj=1.01e-02 nnz(X,L,W)/p=[8.39e+01 5.00e+01 9.98e+01] lns_iter=1
# * iter=39 time=6.02e-02 obj=1.38e+02 |delta(obj)|/obj=8.47e-03 nnz(X,L,W)/p=[8.39e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=40 time=5.90e-02 obj=1.37e+02 |delta(obj)|/obj=6.29e-03 nnz(X,L,W)/p=[8.39e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=41 time=5.84e-02 obj=1.37e+02 |delta(obj)|/obj=4.27e-03 nnz(X,L,W)/p=[8.39e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=42 time=6.21e-02 obj=1.36e+02 |delta(obj)|/obj=2.70e-03 nnz(X,L,W)/p=[8.39e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=43 time=5.49e-02 obj=1.36e+02 |delta(obj)|/obj=7.85e-04 nnz(X,L,W)/p=[8.39e+01 5.00e+01 1.00e+02] lns_iter=1
# #SQUIC Finished: time=2.48e+00 nnz(X,W)/p=[8.39e+01 1.00e+02]
#
# required time: 2.49
# nnz = 1492 per rows = 14.92
#  Matrix is symmetric per rho 0.2
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    1.590000e+01
#  Y:         100 x 200
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      1.000000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=7.92e+01 time=4.27e-04
# * iter=1 time=2.20e-03 obj=6.52e+03 |delta(obj)|/obj=9.85e-01 nnz(X,L,W)/p=[7.92e+01 5.00e+01 1.00e+00] lns_iter=7
# * iter=2 time=4.25e-03 obj=6.50e+03 |delta(obj)|/obj=2.76e-03 nnz(X,L,W)/p=[7.92e+01 5.00e+01 9.31e+01] lns_iter=10
# * iter=3 time=1.90e-02 obj=4.88e+03 |delta(obj)|/obj=3.33e-01 nnz(X,L,W)/p=[7.93e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=4 time=2.17e-02 obj=3.67e+03 |delta(obj)|/obj=3.29e-01 nnz(X,L,W)/p=[8.38e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=5 time=2.17e-02 obj=3.22e+03 |delta(obj)|/obj=1.40e-01 nnz(X,L,W)/p=[8.42e+01 5.00e+01 1.00e+02] lns_iter=4
# * iter=6 time=3.16e-02 obj=2.44e+03 |delta(obj)|/obj=3.21e-01 nnz(X,L,W)/p=[8.42e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=7 time=4.46e-02 obj=2.44e+03 |delta(obj)|/obj=7.97e-04 nnz(X,L,W)/p=[9.99e+01 5.00e+01 1.00e+02] lns_iter=1
# #SQUIC Finished: time=1.46e-01 nnz(X,W)/p=[9.99e+01 1.00e+02]
#
# required time: 0.15
# nnz = 4114 per rows = 41.14
#  Matrix is symmetric per rho 0.1
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    1.590000e+01
#  Y:         100 x 200
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      9.000000e-02
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=7.95e+01 time=4.74e-04
# * iter=1 time=2.38e-03 obj=6.52e+03 |delta(obj)|/obj=9.85e-01 nnz(X,L,W)/p=[7.95e+01 5.00e+01 1.00e+00] lns_iter=7
# * iter=2 time=4.26e-03 obj=6.50e+03 |delta(obj)|/obj=2.75e-03 nnz(X,L,W)/p=[7.95e+01 5.00e+01 9.37e+01] lns_iter=10
# * iter=3 time=1.95e-02 obj=4.88e+03 |delta(obj)|/obj=3.33e-01 nnz(X,L,W)/p=[7.96e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=4 time=2.07e-02 obj=2.46e+03 |delta(obj)|/obj=9.83e-01 nnz(X,L,W)/p=[8.19e+01 5.00e+01 9.99e+01] lns_iter=2
# * iter=5 time=2.14e-02 obj=1.86e+03 |delta(obj)|/obj=3.24e-01 nnz(X,L,W)/p=[8.32e+01 5.00e+01 9.99e+01] lns_iter=3
# * iter=6 time=3.08e-02 obj=1.41e+03 |delta(obj)|/obj=3.20e-01 nnz(X,L,W)/p=[8.36e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=7 time=3.14e-02 obj=1.07e+03 |delta(obj)|/obj=3.13e-01 nnz(X,L,W)/p=[8.39e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=8 time=3.16e-02 obj=8.29e+02 |delta(obj)|/obj=2.93e-01 nnz(X,L,W)/p=[8.42e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=9 time=4.10e-02 obj=6.63e+02 |delta(obj)|/obj=2.50e-01 nnz(X,L,W)/p=[8.43e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=10 time=4.41e-02 obj=5.86e+02 |delta(obj)|/obj=1.32e-01 nnz(X,L,W)/p=[8.66e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=11 time=4.57e-02 obj=4.92e+02 |delta(obj)|/obj=1.92e-01 nnz(X,L,W)/p=[8.77e+01 5.00e+01 1.00e+02] lns_iter=2
# * iter=12 time=5.92e-02 obj=4.70e+02 |delta(obj)|/obj=4.54e-02 nnz(X,L,W)/p=[8.95e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=13 time=5.84e-02 obj=4.56e+02 |delta(obj)|/obj=3.11e-02 nnz(X,L,W)/p=[8.95e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=14 time=5.79e-02 obj=4.46e+02 |delta(obj)|/obj=2.36e-02 nnz(X,L,W)/p=[8.95e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=15 time=6.75e-02 obj=4.33e+02 |delta(obj)|/obj=3.02e-02 nnz(X,L,W)/p=[8.95e+01 5.00e+01 1.00e+02] lns_iter=2
# * iter=16 time=6.69e-02 obj=4.25e+02 |delta(obj)|/obj=1.81e-02 nnz(X,L,W)/p=[8.95e+01 5.00e+01 1.00e+02] lns_iter=2
# * iter=17 time=6.51e-02 obj=4.14e+02 |delta(obj)|/obj=2.69e-02 nnz(X,L,W)/p=[8.95e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=18 time=7.66e-02 obj=4.07e+02 |delta(obj)|/obj=1.67e-02 nnz(X,L,W)/p=[8.96e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=19 time=7.42e-02 obj=3.94e+02 |delta(obj)|/obj=3.24e-02 nnz(X,L,W)/p=[8.96e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=20 time=7.34e-02 obj=3.81e+02 |delta(obj)|/obj=3.38e-02 nnz(X,L,W)/p=[8.96e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=21 time=8.75e-02 obj=3.69e+02 |delta(obj)|/obj=3.31e-02 nnz(X,L,W)/p=[8.96e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=22 time=8.37e-02 obj=3.57e+02 |delta(obj)|/obj=3.51e-02 nnz(X,L,W)/p=[8.96e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=23 time=8.44e-02 obj=3.50e+02 |delta(obj)|/obj=2.01e-02 nnz(X,L,W)/p=[8.96e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=24 time=9.29e-02 obj=3.37e+02 |delta(obj)|/obj=3.88e-02 nnz(X,L,W)/p=[8.96e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=25 time=9.35e-02 obj=3.29e+02 |delta(obj)|/obj=2.44e-02 nnz(X,L,W)/p=[8.96e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=26 time=9.27e-02 obj=3.17e+02 |delta(obj)|/obj=3.67e-02 nnz(X,L,W)/p=[8.96e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=27 time=1.03e-01 obj=3.08e+02 |delta(obj)|/obj=2.85e-02 nnz(X,L,W)/p=[8.96e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=28 time=1.03e-01 obj=2.98e+02 |delta(obj)|/obj=3.31e-02 nnz(X,L,W)/p=[8.96e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=29 time=1.03e-01 obj=2.89e+02 |delta(obj)|/obj=3.10e-02 nnz(X,L,W)/p=[8.96e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=30 time=1.13e-01 obj=2.80e+02 |delta(obj)|/obj=3.28e-02 nnz(X,L,W)/p=[8.96e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=31 time=1.15e-01 obj=2.73e+02 |delta(obj)|/obj=2.60e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=32 time=1.12e-01 obj=2.64e+02 |delta(obj)|/obj=3.32e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=33 time=1.24e-01 obj=2.58e+02 |delta(obj)|/obj=2.29e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=34 time=1.22e-01 obj=2.50e+02 |delta(obj)|/obj=3.36e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=35 time=1.24e-01 obj=2.45e+02 |delta(obj)|/obj=1.86e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=36 time=1.32e-01 obj=2.37e+02 |delta(obj)|/obj=3.48e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=37 time=1.34e-01 obj=2.31e+02 |delta(obj)|/obj=2.44e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=38 time=1.33e-01 obj=2.24e+02 |delta(obj)|/obj=3.31e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=39 time=1.47e-01 obj=2.19e+02 |delta(obj)|/obj=2.21e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=40 time=1.42e-01 obj=2.13e+02 |delta(obj)|/obj=3.12e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=41 time=1.38e-01 obj=2.06e+02 |delta(obj)|/obj=3.10e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=42 time=1.57e-01 obj=2.00e+02 |delta(obj)|/obj=3.34e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=43 time=1.46e-01 obj=1.94e+02 |delta(obj)|/obj=2.94e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=44 time=1.44e-01 obj=1.88e+02 |delta(obj)|/obj=2.88e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=45 time=1.55e-01 obj=1.82e+02 |delta(obj)|/obj=3.26e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=46 time=1.58e-01 obj=1.78e+02 |delta(obj)|/obj=2.29e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=47 time=1.57e-01 obj=1.73e+02 |delta(obj)|/obj=2.86e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=48 time=1.65e-01 obj=1.69e+02 |delta(obj)|/obj=2.84e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=49 time=1.64e-01 obj=1.64e+02 |delta(obj)|/obj=2.52e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=50 time=1.62e-01 obj=1.60e+02 |delta(obj)|/obj=2.80e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=51 time=1.71e-01 obj=1.56e+02 |delta(obj)|/obj=2.59e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=52 time=1.69e-01 obj=1.52e+02 |delta(obj)|/obj=2.83e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=53 time=1.67e-01 obj=1.48e+02 |delta(obj)|/obj=2.73e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=54 time=1.77e-01 obj=1.44e+02 |delta(obj)|/obj=2.88e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=55 time=1.78e-01 obj=1.40e+02 |delta(obj)|/obj=2.68e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=56 time=1.77e-01 obj=1.36e+02 |delta(obj)|/obj=2.79e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=57 time=1.90e-01 obj=1.33e+02 |delta(obj)|/obj=2.59e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=58 time=1.82e-01 obj=1.29e+02 |delta(obj)|/obj=2.74e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=59 time=1.80e-01 obj=1.26e+02 |delta(obj)|/obj=2.59e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=60 time=1.85e-01 obj=1.22e+02 |delta(obj)|/obj=2.68e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=61 time=1.82e-01 obj=1.20e+02 |delta(obj)|/obj=2.44e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=62 time=1.76e-01 obj=1.16e+02 |delta(obj)|/obj=2.66e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=63 time=1.81e-01 obj=1.13e+02 |delta(obj)|/obj=2.61e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=64 time=1.77e-01 obj=1.11e+02 |delta(obj)|/obj=2.60e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=65 time=1.74e-01 obj=1.08e+02 |delta(obj)|/obj=2.53e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=66 time=1.77e-01 obj=1.05e+02 |delta(obj)|/obj=2.55e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=67 time=1.73e-01 obj=1.03e+02 |delta(obj)|/obj=2.59e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=68 time=1.65e-01 obj=1.00e+02 |delta(obj)|/obj=2.58e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=69 time=1.65e-01 obj=9.74e+01 |delta(obj)|/obj=2.63e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=70 time=1.55e-01 obj=9.49e+01 |delta(obj)|/obj=2.63e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 9.98e+01] lns_iter=1
# * iter=71 time=1.42e-01 obj=9.27e+01 |delta(obj)|/obj=2.41e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=72 time=1.38e-01 obj=9.06e+01 |delta(obj)|/obj=2.30e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=73 time=1.30e-01 obj=8.88e+01 |delta(obj)|/obj=1.99e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=74 time=1.17e-01 obj=8.74e+01 |delta(obj)|/obj=1.63e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=75 time=1.19e-01 obj=8.62e+01 |delta(obj)|/obj=1.37e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=76 time=1.04e-01 obj=8.53e+01 |delta(obj)|/obj=1.08e-02 nnz(X,L,W)/p=[8.97e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=77 time=9.55e-02 obj=8.47e+01 |delta(obj)|/obj=6.56e-03 nnz(X,L,W)/p=[8.97e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=78 time=9.24e-02 obj=8.44e+01 |delta(obj)|/obj=3.50e-03 nnz(X,L,W)/p=[8.97e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=79 time=9.90e-02 obj=8.43e+01 |delta(obj)|/obj=1.79e-03 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=80 time=9.73e-02 obj=8.42e+01 |delta(obj)|/obj=1.27e-03 nnz(X,L,W)/p=[8.97e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=81 time=9.50e-02 obj=8.41e+01 |delta(obj)|/obj=9.61e-04 nnz(X,L,W)/p=[8.97e+01 5.00e+01 9.99e+01] lns_iter=1
# #SQUIC Finished: time=9.41e+00 nnz(X,W)/p=[8.97e+01 9.99e+01]
#
# required time: 9.42
# nnz = 1694 per rows = 16.94
#  Matrix is symmetric per rho 0.09
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    1.590000e+01
#  Y:         100 x 200
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      5.000000e-02
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=8.13e+01 time=4.35e-04
# * iter=1 time=2.41e-03 obj=6.51e+03 |delta(obj)|/obj=9.85e-01 nnz(X,L,W)/p=[8.13e+01 5.00e+01 3.87e+01] lns_iter=7
# * iter=2 time=7.90e-03 obj=6.46e+03 |delta(obj)|/obj=8.35e-03 nnz(X,L,W)/p=[8.13e+01 5.00e+01 9.44e+01] lns_iter=8
# * iter=3 time=1.99e-02 obj=5.65e+03 |delta(obj)|/obj=1.44e-01 nnz(X,L,W)/p=[8.17e+01 5.00e+01 1.00e+02] lns_iter=4
# * iter=4 time=2.04e-02 obj=2.83e+03 |delta(obj)|/obj=9.95e-01 nnz(X,L,W)/p=[8.20e+01 5.00e+01 9.99e+01] lns_iter=2
# * iter=5 time=2.18e-02 obj=2.13e+03 |delta(obj)|/obj=3.28e-01 nnz(X,L,W)/p=[8.42e+01 5.00e+01 9.95e+01] lns_iter=3
# * iter=6 time=3.14e-02 obj=1.61e+03 |delta(obj)|/obj=3.25e-01 nnz(X,L,W)/p=[8.42e+01 5.00e+01 9.99e+01] lns_iter=3
# * iter=7 time=3.12e-02 obj=1.22e+03 |delta(obj)|/obj=3.21e-01 nnz(X,L,W)/p=[8.42e+01 5.00e+01 9.99e+01] lns_iter=3
# * iter=8 time=3.15e-02 obj=9.29e+02 |delta(obj)|/obj=3.11e-01 nnz(X,L,W)/p=[8.42e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=9 time=4.12e-02 obj=7.45e+02 |delta(obj)|/obj=2.46e-01 nnz(X,L,W)/p=[8.43e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=10 time=4.16e-02 obj=6.85e+02 |delta(obj)|/obj=8.79e-02 nnz(X,L,W)/p=[8.47e+01 5.00e+01 1.00e+02] lns_iter=4
# * iter=11 time=4.19e-02 obj=5.94e+02 |delta(obj)|/obj=1.52e-01 nnz(X,L,W)/p=[8.48e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=12 time=5.21e-02 obj=5.38e+02 |delta(obj)|/obj=1.05e-01 nnz(X,L,W)/p=[8.52e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=13 time=5.23e-02 obj=5.05e+02 |delta(obj)|/obj=6.53e-02 nnz(X,L,W)/p=[8.54e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=14 time=5.23e-02 obj=4.63e+02 |delta(obj)|/obj=9.04e-02 nnz(X,L,W)/p=[8.54e+01 5.00e+01 1.00e+02] lns_iter=2
# * iter=15 time=6.11e-02 obj=4.44e+02 |delta(obj)|/obj=4.28e-02 nnz(X,L,W)/p=[8.54e+01 5.00e+01 1.00e+02] lns_iter=2
# * iter=16 time=6.16e-02 obj=4.31e+02 |delta(obj)|/obj=3.07e-02 nnz(X,L,W)/p=[8.54e+01 5.00e+01 1.00e+02] lns_iter=2
# * iter=17 time=6.05e-02 obj=4.10e+02 |delta(obj)|/obj=5.07e-02 nnz(X,L,W)/p=[8.54e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=18 time=7.38e-02 obj=4.02e+02 |delta(obj)|/obj=2.02e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=19 time=7.29e-02 obj=3.90e+02 |delta(obj)|/obj=3.09e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=20 time=7.21e-02 obj=3.75e+02 |delta(obj)|/obj=4.05e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=21 time=8.26e-02 obj=3.63e+02 |delta(obj)|/obj=3.22e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=22 time=8.22e-02 obj=3.50e+02 |delta(obj)|/obj=3.76e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=23 time=8.23e-02 obj=3.41e+02 |delta(obj)|/obj=2.49e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=24 time=9.26e-02 obj=3.32e+02 |delta(obj)|/obj=2.91e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=25 time=9.32e-02 obj=3.25e+02 |delta(obj)|/obj=2.12e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=26 time=9.23e-02 obj=3.14e+02 |delta(obj)|/obj=3.59e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=27 time=1.03e-01 obj=3.05e+02 |delta(obj)|/obj=2.91e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=28 time=1.02e-01 obj=2.95e+02 |delta(obj)|/obj=3.20e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=29 time=1.14e-01 obj=2.86e+02 |delta(obj)|/obj=3.10e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=30 time=1.12e-01 obj=2.76e+02 |delta(obj)|/obj=3.61e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=31 time=1.13e-01 obj=2.70e+02 |delta(obj)|/obj=2.47e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=32 time=1.12e-01 obj=2.60e+02 |delta(obj)|/obj=3.62e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=33 time=1.23e-01 obj=2.53e+02 |delta(obj)|/obj=3.02e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=34 time=1.21e-01 obj=2.44e+02 |delta(obj)|/obj=3.68e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=35 time=1.21e-01 obj=2.35e+02 |delta(obj)|/obj=3.62e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=36 time=1.32e-01 obj=2.26e+02 |delta(obj)|/obj=4.00e-02 nnz(X,L,W)/p=[8.59e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=37 time=1.34e-01 obj=2.21e+02 |delta(obj)|/obj=2.24e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=38 time=1.31e-01 obj=2.14e+02 |delta(obj)|/obj=3.14e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=39 time=1.41e-01 obj=2.09e+02 |delta(obj)|/obj=2.54e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=40 time=1.38e-01 obj=2.03e+02 |delta(obj)|/obj=3.27e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=41 time=1.39e-01 obj=1.96e+02 |delta(obj)|/obj=3.48e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=42 time=1.48e-01 obj=1.89e+02 |delta(obj)|/obj=3.75e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=43 time=1.50e-01 obj=1.84e+02 |delta(obj)|/obj=2.77e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=44 time=1.54e-01 obj=1.77e+02 |delta(obj)|/obj=3.82e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=45 time=1.60e-01 obj=1.71e+02 |delta(obj)|/obj=3.10e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=46 time=1.59e-01 obj=1.65e+02 |delta(obj)|/obj=3.69e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=47 time=1.59e-01 obj=1.61e+02 |delta(obj)|/obj=2.97e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=48 time=1.69e-01 obj=1.55e+02 |delta(obj)|/obj=3.86e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=49 time=1.68e-01 obj=1.51e+02 |delta(obj)|/obj=2.74e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=50 time=1.68e-01 obj=1.45e+02 |delta(obj)|/obj=4.06e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=51 time=1.77e-01 obj=1.41e+02 |delta(obj)|/obj=2.76e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=52 time=1.78e-01 obj=1.36e+02 |delta(obj)|/obj=3.51e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=53 time=1.76e-01 obj=1.31e+02 |delta(obj)|/obj=3.71e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=54 time=1.84e-01 obj=1.26e+02 |delta(obj)|/obj=3.68e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=55 time=1.84e-01 obj=1.22e+02 |delta(obj)|/obj=3.44e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=56 time=1.83e-01 obj=1.18e+02 |delta(obj)|/obj=3.83e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=57 time=1.91e-01 obj=1.14e+02 |delta(obj)|/obj=3.52e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=58 time=1.91e-01 obj=1.10e+02 |delta(obj)|/obj=3.60e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=59 time=1.90e-01 obj=1.06e+02 |delta(obj)|/obj=3.95e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=60 time=1.98e-01 obj=1.01e+02 |delta(obj)|/obj=4.19e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=61 time=1.98e-01 obj=9.78e+01 |delta(obj)|/obj=3.61e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=62 time=1.95e-01 obj=9.39e+01 |delta(obj)|/obj=4.16e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=63 time=2.03e-01 obj=9.05e+01 |delta(obj)|/obj=3.82e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=64 time=2.02e-01 obj=8.68e+01 |delta(obj)|/obj=4.20e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=65 time=1.98e-01 obj=8.35e+01 |delta(obj)|/obj=4.02e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=66 time=2.08e-01 obj=8.02e+01 |delta(obj)|/obj=4.06e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=67 time=2.06e-01 obj=7.72e+01 |delta(obj)|/obj=3.88e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=68 time=2.02e-01 obj=7.43e+01 |delta(obj)|/obj=3.91e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=69 time=2.07e-01 obj=7.15e+01 |delta(obj)|/obj=3.91e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=70 time=2.03e-01 obj=6.88e+01 |delta(obj)|/obj=3.88e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=71 time=1.94e-01 obj=6.63e+01 |delta(obj)|/obj=3.81e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=72 time=2.07e-01 obj=6.38e+01 |delta(obj)|/obj=3.88e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=73 time=1.75e-01 obj=6.16e+01 |delta(obj)|/obj=3.63e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=74 time=1.65e-01 obj=5.95e+01 |delta(obj)|/obj=3.58e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=75 time=1.57e-01 obj=5.75e+01 |delta(obj)|/obj=3.47e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=76 time=1.44e-01 obj=5.57e+01 |delta(obj)|/obj=3.25e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=77 time=1.32e-01 obj=5.41e+01 |delta(obj)|/obj=2.92e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.98e+01] lns_iter=1
# * iter=78 time=1.41e-01 obj=5.27e+01 |delta(obj)|/obj=2.62e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=79 time=1.25e-01 obj=5.16e+01 |delta(obj)|/obj=2.09e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=80 time=1.23e-01 obj=5.08e+01 |delta(obj)|/obj=1.61e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.98e+01] lns_iter=1
# * iter=81 time=1.30e-01 obj=5.03e+01 |delta(obj)|/obj=1.11e-02 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=82 time=1.20e-01 obj=4.99e+01 |delta(obj)|/obj=7.50e-03 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.98e+01] lns_iter=1
# * iter=83 time=1.21e-01 obj=4.96e+01 |delta(obj)|/obj=5.70e-03 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=84 time=1.20e-01 obj=4.94e+01 |delta(obj)|/obj=4.39e-03 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=85 time=1.22e-01 obj=4.92e+01 |delta(obj)|/obj=3.37e-03 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=86 time=1.13e-01 obj=4.91e+01 |delta(obj)|/obj=2.69e-03 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=87 time=1.33e-01 obj=4.90e+01 |delta(obj)|/obj=2.41e-03 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=88 time=1.13e-01 obj=4.89e+01 |delta(obj)|/obj=2.08e-03 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=89 time=1.00e-01 obj=4.88e+01 |delta(obj)|/obj=1.68e-03 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=90 time=1.02e-01 obj=4.87e+01 |delta(obj)|/obj=1.44e-03 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=91 time=1.03e-01 obj=4.87e+01 |delta(obj)|/obj=1.23e-03 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=92 time=1.01e-01 obj=4.86e+01 |delta(obj)|/obj=1.15e-03 nnz(X,L,W)/p=[8.61e+01 5.00e+01 9.99e+01] lns_iter=1
# * iter=93 time=1.18e-01 obj=4.85e+01 |delta(obj)|/obj=1.10e-03 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=94 time=1.04e-01 obj=4.85e+01 |delta(obj)|/obj=9.43e-04 nnz(X,L,W)/p=[8.61e+01 5.00e+01 1.00e+02] lns_iter=1
# #SQUIC Finished: time=1.17e+01 nnz(X,W)/p=[8.61e+01 1.00e+02]
#
# required time: 11.69
# nnz = 1778 per rows = 17.78
#  Matrix is symmetric per rho 0.05
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    1.590000e+01
#  Y:         100 x 200
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      1.000000e-02
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=8.37e+01 time=4.06e-04
# * iter=1 time=2.17e-03 obj=6.50e+03 |delta(obj)|/obj=9.85e-01 nnz(X,L,W)/p=[8.37e+01 5.00e+01 7.65e+01] lns_iter=7
# * iter=2 time=9.76e-03 obj=5.68e+03 |delta(obj)|/obj=1.44e-01 nnz(X,L,W)/p=[8.37e+01 5.00e+01 1.00e+02] lns_iter=4
# * iter=3 time=2.12e-02 obj=4.27e+03 |delta(obj)|/obj=3.31e-01 nnz(X,L,W)/p=[8.42e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=4 time=2.15e-02 obj=3.74e+03 |delta(obj)|/obj=1.41e-01 nnz(X,L,W)/p=[8.42e+01 5.00e+01 1.00e+02] lns_iter=4
# * iter=5 time=2.15e-02 obj=3.28e+03 |delta(obj)|/obj=1.41e-01 nnz(X,L,W)/p=[8.42e+01 5.00e+01 1.00e+02] lns_iter=4
# * iter=6 time=3.09e-02 obj=2.87e+03 |delta(obj)|/obj=1.40e-01 nnz(X,L,W)/p=[8.42e+01 5.00e+01 1.00e+02] lns_iter=4
# * iter=7 time=3.09e-02 obj=2.71e+03 |delta(obj)|/obj=5.86e-02 nnz(X,L,W)/p=[8.43e+01 5.00e+01 1.00e+02] lns_iter=5
# * iter=8 time=3.57e-02 obj=2.58e+03 |delta(obj)|/obj=5.38e-02 nnz(X,L,W)/p=[8.43e+01 5.00e+01 1.00e+02] lns_iter=5
# * iter=9 time=4.18e-02 obj=2.45e+03 |delta(obj)|/obj=5.00e-02 nnz(X,L,W)/p=[8.44e+01 5.00e+01 1.00e+02] lns_iter=5
# * iter=10 time=4.23e-02 obj=2.27e+03 |delta(obj)|/obj=7.95e-02 nnz(X,L,W)/p=[8.51e+01 5.00e+01 1.00e+02] lns_iter=4
# * iter=11 time=4.53e-02 obj=2.17e+03 |delta(obj)|/obj=4.53e-02 nnz(X,L,W)/p=[8.80e+01 5.00e+01 1.00e+02] lns_iter=4
# * iter=12 time=6.02e-02 obj=2.05e+03 |delta(obj)|/obj=6.00e-02 nnz(X,L,W)/p=[9.08e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=13 time=6.86e-02 obj=2.03e+03 |delta(obj)|/obj=8.64e-03 nnz(X,L,W)/p=[9.65e+01 5.00e+01 1.00e+02] lns_iter=3
# * iter=14 time=7.17e-02 obj=2.02e+03 |delta(obj)|/obj=5.58e-03 nnz(X,L,W)/p=[9.92e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=15 time=8.40e-02 obj=1.98e+03 |delta(obj)|/obj=1.90e-02 nnz(X,L,W)/p=[9.92e+01 5.00e+01 1.00e+02] lns_iter=1
# * iter=16 time=8.68e-02 obj=1.98e+03 |delta(obj)|/obj=9.53e-04 nnz(X,L,W)/p=[9.97e+01 5.00e+01 1.00e+02] lns_iter=1
# #SQUIC Finished: time=6.75e-01 nnz(X,W)/p=[9.97e+01 1.00e+02]
#
# required time: 0.68
# nnz = 4198 per rows = 41.98
#  Matrix is symmetric per rho 0.01

# %%
# Use the extracted W for clustering
dict_cluster = clustering(A_matrices)

# Report internal metrics on the clustering
int_metrics = internal_metrics(dict_cluster, A_matrices)
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 134.87it/s]
# Best params: eps=0.1, min_samples=3
# Best difference in number of clusters: 29.0000
# Best difference in number of clusters: 29.0000
# /opt/anaconda3/envs/bank/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# 100%|██████████| 20/20 [00:00<00:00, 209.10it/s]
# /opt/anaconda3/envs/bank/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# Best params: eps=0.1, min_samples=3
# Best difference in number of clusters: 12.0000
# Best difference in number of clusters: 12.0000
# 100%|██████████| 20/20 [00:00<00:00, 225.44it/s]
# Best params: eps=0.4, min_samples=3
# Best difference in number of clusters: 0.0000
# Best difference in number of clusters: 0.0000
# 100%|██████████| 20/20 [00:00<00:00, 207.89it/s]
# Best params: eps=0.2, min_samples=3
# Best difference in number of clusters: 3.0000
# Best difference in number of clusters: 3.0000
# 100%|██████████| 20/20 [00:00<00:00, 191.61it/s]
# Best params: eps=0.9999999999999999, min_samples=3
# Best difference in number of clusters: 0.0000
# Best difference in number of clusters: 0.0000
# 100%|██████████| 20/20 [00:00<00:00, 201.25it/s]
# Best params: eps=1.7, min_samples=3
# Best difference in number of clusters: 1.0000
# Best difference in number of clusters: 1.0000
# 100%|██████████| 20/20 [00:00<00:00, 191.10it/s]
# Best params: eps=0.3, min_samples=3
# Best difference in number of clusters: 1.0000
# Best difference in number of clusters: 1.0000

# %%
visualize_metrics(int_metrics)
# Out:
# For rho = 0.9
#     louvain : {'ncut': 1.03, 'rcut': 0.12, 'modularity': 0.38, 'CC': 29, 'nCluster': 32}
#     dbscan : {'ncut': 2.04, 'rcut': 0.86, 'modularity': 0.0, 'CC': 29, 'nCluster': 3}
#     spectral : {'ncut': 27.99, 'rcut': 5.81, 'modularity': 0.08, 'CC': 29, 'nCluster': 32}
#
#
# For rho = 0.5
#     louvain : {'ncut': 0.6, 'rcut': 0.19, 'modularity': 0.54, 'CC': 2, 'nCluster': 6}
#     dbscan : {'ncut': 17.16, 'rcut': 7.46, 'modularity': 0.04, 'CC': 2, 'nCluster': 18}
#     spectral : {'ncut': 1.14, 'rcut': 0.31, 'modularity': 0.52, 'CC': 2, 'nCluster': 6}
#
#
# For rho = 0.2
#     louvain : {'ncut': 1.06, 'rcut': 0.88, 'modularity': 0.59, 'CC': 1, 'nCluster': 5}
#     dbscan : {'ncut': 4.07, 'rcut': 6.13, 'modularity': -0.0, 'CC': 1, 'nCluster': 5}
#     spectral : {'ncut': 1.12, 'rcut': 0.93, 'modularity': 0.57, 'CC': 1, 'nCluster': 5}
#
#
# For rho = 0.1
#     louvain : {'ncut': 1.35, 'rcut': 0.95, 'modularity': 0.44, 'CC': 1, 'nCluster': 4}
#     dbscan : {'ncut': 6.1, 'rcut': 6.39, 'modularity': -0.0, 'CC': 1, 'nCluster': 7}
#     spectral : {'ncut': 1.4, 'rcut': 0.99, 'modularity': 0.42, 'CC': 1, 'nCluster': 4}
#
#
# For rho = 0.09
#     louvain : {'ncut': 1.23, 'rcut': 2.45, 'modularity': 0.57, 'CC': 1, 'nCluster': 5}
#     dbscan : {'ncut': 4.06, 'rcut': 12.96, 'modularity': -0.0, 'CC': 1, 'nCluster': 5}
#     spectral : {'ncut': 1.31, 'rcut': 2.67, 'modularity': 0.56, 'CC': 1, 'nCluster': 5}
#
#
# For rho = 0.05
#     louvain : {'ncut': 1.48, 'rcut': 5.02, 'modularity': 0.53, 'CC': 1, 'nCluster': 5}
#     dbscan : {'ncut': 5.1, 'rcut': 32.14, 'modularity': -0.01, 'CC': 1, 'nCluster': 6}
#     spectral : {'ncut': 1.69, 'rcut': 5.84, 'modularity': 0.48, 'CC': 1, 'nCluster': 5}
#
#
# For rho = 0.01
#     louvain : {'ncut': 0.95, 'rcut': 0.89, 'modularity': 0.37, 'CC': 1, 'nCluster': 3}
#     dbscan : {'ncut': 1.03, 'rcut': 2.08, 'modularity': -0.0, 'CC': 1, 'nCluster': 2}
#     spectral : {'ncut': 1.04, 'rcut': 0.84, 'modularity': 0.33, 'CC': 1, 'nCluster': 3}

# %%
# Visualise with cosmograph
widget_dict = visualize_graph_internal(A_matrices, dict_cluster, account_prop)

# %%
rho = 0.5

# %%
widget_dict[rho]['louvain']
# Out:
# Cosmograph(background_color=None, focused_point_ring_color=None, hovered_point_ring_color=None, link_color=Non…

# %%
widget_dict[rho]["spectral"]
# Out:
# Cosmograph(background_color=None, focused_point_ring_color=None, hovered_point_ring_color=None, link_color=Non…

# %%
widget_dict[rho]["dbscan"]
# Out:
# Cosmograph(background_color=None, focused_point_ring_color=None, hovered_point_ring_color=None, link_color=Non…

# %%
lists = extract_results(int_metrics)

# %%
plot_results('ncut', 'N Cut', lists)
plot_results('ncut', 'N Cut', lists, ['louvain', 'spectral'])

# %%
plot_results('rcut', 'Ratio Cut', lists)
plot_results('rcut', 'Ratio Cut', lists, methods=['louvain', 'spectral'])

# %%
plot_results('modularity', 'Modularity', lists)
plot_results('modularity', 'Modularity', lists, methods=['louvain', 'spectral'])

# %%
plot_results('nCluster', 'num Cluster', lists)

# %%
def plot_results_2(metrics, ylabel, results, methods=['louvain', 'spectral', 'dbscan']):
    # Create the plot
    plt.figure(figsize=(6, 6))

    colors = ['steelblue', 'gold', 'indianred']
    dot = ['o-', 's-', '^-']

    if methods == ['louvain', 'spectral']:
        for i, method in enumerate(methods): 
            plt.plot(results['rho_values'], results[f'{method}_{metrics}'], dot[i], label=f'{method}', color=colors[i])
        
        plt.yscale('log')
    
    else:
        plt.plot(results['rho_values'], results[f'louvain_{metrics}'], 'o-', label='Louvain', color=colors[0])
        plt.plot(results['rho_values'], results[f'spectral_{metrics}'], 's-', label='Spectral', color=colors[1])
        plt.plot(results['rho_values'], results[f'dbscan_{metrics}'], '^-', label='DBSCAN', color=colors[2])
    # plt.plot(results['rho_values'], results[f'dbscan_{metrics}'], '^-', color=colors[0])


    plt.xlabel('Reg. Parameter (λ)', fontsize=22)
    plt.ylabel(ylabel, fontsize=22)
    plt.xscale('log')
    plt.yscale('log')
    plt.tick_params(axis='x', labelsize=22)
    plt.tick_params(axis='y', labelsize=22)
    plt.show()

# %%
plot_results_2('CC', 'Connected Components', lists)
