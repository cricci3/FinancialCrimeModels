# %%
from workflow.internal import *

# Load dataset (the user will pass the name)
df, name, dimension, account_prop = load_dataset()

# Extract time series
extract_timeseries(df, name)

# Normalise time series
Y_norm = normalization(df, name)

# Create transaction matrix
adj_matrix = adjaceny_matrix(Y_norm, name, dimension)

# Run SQUIC_fit
A_matrices, _ = squic_fit_computation(Y_norm, name, dimension, adj_matrix, printMatrix=True)
# Out:
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    2.763964e+01
#  Y:         111 x 364
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      9.000000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=3.36e+00 time=7.45e-04
# * iter=1 time=9.89e-04 obj=1.82e+02 |delta(obj)|/obj=3.92e-01 nnz(X,L,W)/p=[3.36e+00 2.09e+00 1.52e+00] lns_iter=2
# * iter=2 time=1.26e-03 obj=1.82e+02 |delta(obj)|/obj=6.43e-06 nnz(X,L,W)/p=[3.36e+00 2.09e+00 4.62e+00] lns_iter=1
# #SQUIC Finished: time=3.26e-03 nnz(X,W)/p=[3.36e+00 4.62e+00]
#
# required time: 0.01
# nnz = 353 per rows = 3.18
# ✅ Matrix is symmetric per rho 0.9
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    2.763964e+01
#  Y:         111 x 364
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      5.000000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=2.64e+01 time=5.34e-04
# * iter=1 time=1.54e-03 obj=1.56e+02 |delta(obj)|/obj=2.87e-01 nnz(X,L,W)/p=[2.64e+01 2.59e+01 1.00e+00] lns_iter=5
# * iter=2 time=2.43e-03 obj=1.54e+02 |delta(obj)|/obj=1.19e-02 nnz(X,L,W)/p=[2.64e+01 2.59e+01 3.81e+01] lns_iter=7
# * iter=3 time=6.09e-03 obj=1.49e+02 |delta(obj)|/obj=3.59e-02 nnz(X,L,W)/p=[2.64e+01 2.59e+01 9.11e+01] lns_iter=3
# * iter=4 time=7.67e-03 obj=1.46e+02 |delta(obj)|/obj=1.75e-02 nnz(X,L,W)/p=[2.64e+01 2.59e+01 9.74e+01] lns_iter=1
# * iter=5 time=4.57e-03 obj=1.46e+02 |delta(obj)|/obj=3.28e-03 nnz(X,L,W)/p=[2.64e+01 2.73e+01 9.73e+01] lns_iter=1
# * iter=6 time=6.08e-03 obj=1.45e+02 |delta(obj)|/obj=4.04e-04 nnz(X,L,W)/p=[2.64e+01 2.73e+01 9.74e+01] lns_iter=1
# #SQUIC Finished: time=2.94e-02 nnz(X,W)/p=[2.64e+01 9.74e+01]
#
# required time: 0.03
# nnz = 1621 per rows = 14.6
# ✅ Matrix is symmetric per rho 0.5
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    2.763964e+01
#  Y:         111 x 364
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      2.000000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=5.75e+01 time=5.70e-04
# * iter=1 time=2.93e-03 obj=1.08e+02 |delta(obj)|/obj=2.87e-02 nnz(X,L,W)/p=[5.75e+01 4.71e+01 1.00e+00] lns_iter=6
# * iter=2 time=4.14e-03 obj=1.03e+02 |delta(obj)|/obj=4.63e-02 nnz(X,L,W)/p=[5.75e+01 4.71e+01 1.08e+02] lns_iter=8
# * iter=3 time=1.86e-02 obj=9.54e+01 |delta(obj)|/obj=8.08e-02 nnz(X,L,W)/p=[5.79e+01 4.71e+01 1.09e+02] lns_iter=4
# * iter=4 time=1.90e-02 obj=8.97e+01 |delta(obj)|/obj=6.39e-02 nnz(X,L,W)/p=[5.85e+01 4.62e+01 1.10e+02] lns_iter=3
# * iter=5 time=1.85e-02 obj=8.23e+01 |delta(obj)|/obj=9.00e-02 nnz(X,L,W)/p=[5.92e+01 4.75e+01 1.11e+02] lns_iter=1
# * iter=6 time=1.31e-02 obj=8.05e+01 |delta(obj)|/obj=2.21e-02 nnz(X,L,W)/p=[6.35e+01 4.72e+01 1.11e+02] lns_iter=1
# * iter=7 time=1.11e-02 obj=7.97e+01 |delta(obj)|/obj=1.01e-02 nnz(X,L,W)/p=[6.35e+01 4.72e+01 1.11e+02] lns_iter=1
# * iter=8 time=9.85e-03 obj=7.94e+01 |delta(obj)|/obj=3.55e-03 nnz(X,L,W)/p=[6.35e+01 4.72e+01 1.11e+02] lns_iter=1
# * iter=9 time=1.19e-02 obj=7.93e+01 |delta(obj)|/obj=1.83e-03 nnz(X,L,W)/p=[6.35e+01 4.72e+01 1.11e+02] lns_iter=1
# * iter=10 time=1.18e-02 obj=7.92e+01 |delta(obj)|/obj=8.17e-04 nnz(X,L,W)/p=[6.35e+01 4.72e+01 1.11e+02] lns_iter=1
# #SQUIC Finished: time=1.22e-01 nnz(X,W)/p=[6.35e+01 1.11e+02]
#
# required time: 0.13
# nnz = 1879 per rows = 16.93
# ✅ Matrix is symmetric per rho 0.2
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    2.763964e+01
#  Y:         111 x 364
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      1.000000e-01
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=6.95e+01 time=6.69e-04
# * iter=1 time=2.40e-03 obj=8.42e+01 |delta(obj)|/obj=3.18e-01 nnz(X,L,W)/p=[6.95e+01 4.84e+01 3.07e+01] lns_iter=6
# * iter=2 time=6.73e-03 obj=7.79e+01 |delta(obj)|/obj=8.10e-02 nnz(X,L,W)/p=[6.96e+01 4.84e+01 1.10e+02] lns_iter=6
# * iter=3 time=4.53e-02 obj=6.59e+01 |delta(obj)|/obj=1.81e-01 nnz(X,L,W)/p=[7.80e+01 4.87e+01 1.11e+02] lns_iter=3
# * iter=4 time=3.11e-02 obj=5.65e+01 |delta(obj)|/obj=1.66e-01 nnz(X,L,W)/p=[8.22e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=5 time=2.94e-02 obj=5.15e+01 |delta(obj)|/obj=9.78e-02 nnz(X,L,W)/p=[8.28e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=6 time=3.76e-02 obj=4.42e+01 |delta(obj)|/obj=1.65e-01 nnz(X,L,W)/p=[8.28e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=7 time=2.44e-02 obj=3.88e+01 |delta(obj)|/obj=1.38e-01 nnz(X,L,W)/p=[8.28e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=8 time=1.71e-02 obj=3.60e+01 |delta(obj)|/obj=7.93e-02 nnz(X,L,W)/p=[8.29e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=9 time=1.92e-02 obj=3.38e+01 |delta(obj)|/obj=6.43e-02 nnz(X,L,W)/p=[8.29e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=10 time=1.67e-02 obj=3.29e+01 |delta(obj)|/obj=2.79e-02 nnz(X,L,W)/p=[8.29e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=11 time=1.66e-02 obj=3.23e+01 |delta(obj)|/obj=1.80e-02 nnz(X,L,W)/p=[8.29e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=12 time=1.84e-02 obj=3.19e+01 |delta(obj)|/obj=1.10e-02 nnz(X,L,W)/p=[8.29e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=13 time=1.77e-02 obj=3.17e+01 |delta(obj)|/obj=6.56e-03 nnz(X,L,W)/p=[8.29e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=14 time=1.73e-02 obj=3.16e+01 |delta(obj)|/obj=4.22e-03 nnz(X,L,W)/p=[8.29e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=15 time=1.99e-02 obj=3.15e+01 |delta(obj)|/obj=3.46e-03 nnz(X,L,W)/p=[8.29e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=16 time=1.95e-02 obj=3.14e+01 |delta(obj)|/obj=2.37e-03 nnz(X,L,W)/p=[8.29e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=17 time=1.93e-02 obj=3.14e+01 |delta(obj)|/obj=1.66e-03 nnz(X,L,W)/p=[8.29e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=18 time=2.25e-02 obj=3.13e+01 |delta(obj)|/obj=1.45e-03 nnz(X,L,W)/p=[8.29e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=19 time=2.17e-02 obj=3.13e+01 |delta(obj)|/obj=1.01e-03 nnz(X,L,W)/p=[8.29e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=20 time=2.14e-02 obj=3.13e+01 |delta(obj)|/obj=7.55e-04 nnz(X,L,W)/p=[8.29e+01 4.94e+01 1.11e+02] lns_iter=1
# #SQUIC Finished: time=4.26e-01 nnz(X,W)/p=[8.29e+01 1.11e+02]
#
# required time: 0.43
# nnz = 1927 per rows = 17.36
# ✅ Matrix is symmetric per rho 0.1
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    2.763964e+01
#  Y:         111 x 364
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      9.000000e-02
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=7.10e+01 time=4.84e-04
# * iter=1 time=2.40e-03 obj=8.18e+01 |delta(obj)|/obj=3.58e-01 nnz(X,L,W)/p=[7.10e+01 4.87e+01 3.83e+01] lns_iter=6
# * iter=2 time=7.99e-03 obj=7.58e+01 |delta(obj)|/obj=7.83e-02 nnz(X,L,W)/p=[7.13e+01 4.87e+01 1.10e+02] lns_iter=6
# * iter=3 time=3.04e-02 obj=6.34e+01 |delta(obj)|/obj=1.97e-01 nnz(X,L,W)/p=[7.96e+01 4.89e+01 1.11e+02] lns_iter=3
# * iter=4 time=3.11e-02 obj=5.30e+01 |delta(obj)|/obj=1.95e-01 nnz(X,L,W)/p=[8.28e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=5 time=3.01e-02 obj=4.76e+01 |delta(obj)|/obj=1.14e-01 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.10e+02] lns_iter=1
# * iter=6 time=3.93e-02 obj=4.02e+01 |delta(obj)|/obj=1.84e-01 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=7 time=2.63e-02 obj=3.40e+01 |delta(obj)|/obj=1.82e-01 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=8 time=1.97e-02 obj=3.05e+01 |delta(obj)|/obj=1.13e-01 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.10e+02] lns_iter=1
# * iter=9 time=2.11e-02 obj=2.78e+01 |delta(obj)|/obj=9.87e-02 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=10 time=1.87e-02 obj=2.64e+01 |delta(obj)|/obj=5.16e-02 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=11 time=1.91e-02 obj=2.57e+01 |delta(obj)|/obj=2.87e-02 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=12 time=1.96e-02 obj=2.52e+01 |delta(obj)|/obj=1.88e-02 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=13 time=1.91e-02 obj=2.49e+01 |delta(obj)|/obj=1.13e-02 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=14 time=1.85e-02 obj=2.47e+01 |delta(obj)|/obj=7.64e-03 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=15 time=2.10e-02 obj=2.46e+01 |delta(obj)|/obj=6.06e-03 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=16 time=2.02e-02 obj=2.45e+01 |delta(obj)|/obj=4.15e-03 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=17 time=1.99e-02 obj=2.44e+01 |delta(obj)|/obj=2.91e-03 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=18 time=2.28e-02 obj=2.44e+01 |delta(obj)|/obj=2.38e-03 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=19 time=2.24e-02 obj=2.43e+01 |delta(obj)|/obj=1.75e-03 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=20 time=2.21e-02 obj=2.43e+01 |delta(obj)|/obj=1.31e-03 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=21 time=2.46e-02 obj=2.43e+01 |delta(obj)|/obj=1.14e-03 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=22 time=2.44e-02 obj=2.42e+01 |delta(obj)|/obj=9.06e-04 nnz(X,L,W)/p=[8.33e+01 4.94e+01 1.11e+02] lns_iter=1
# #SQUIC Finished: time=4.82e-01 nnz(X,W)/p=[8.33e+01 1.11e+02]
#
# required time: 0.49
# nnz = 1933 per rows = 17.41
# ✅ Matrix is symmetric per rho 0.09
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    2.763964e+01
#  Y:         111 x 364
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      5.000000e-02
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=7.66e+01 time=5.90e-04
# * iter=1 time=2.67e-03 obj=9.25e+01 |delta(obj)|/obj=1.99e-01 nnz(X,L,W)/p=[7.66e+01 4.89e+01 1.00e+00] lns_iter=7
# * iter=2 time=4.58e-03 obj=8.12e+01 |delta(obj)|/obj=1.40e-01 nnz(X,L,W)/p=[7.66e+01 4.89e+01 9.76e+01] lns_iter=8
# * iter=3 time=2.69e-02 obj=6.50e+01 |delta(obj)|/obj=2.49e-01 nnz(X,L,W)/p=[7.69e+01 4.89e+01 1.09e+02] lns_iter=5
# * iter=4 time=2.89e-02 obj=5.23e+01 |delta(obj)|/obj=2.42e-01 nnz(X,L,W)/p=[7.77e+01 4.89e+01 1.09e+02] lns_iter=4
# * iter=5 time=2.89e-02 obj=3.14e+01 |delta(obj)|/obj=6.65e-01 nnz(X,L,W)/p=[7.89e+01 4.89e+01 1.11e+02] lns_iter=2
# * iter=6 time=4.50e-02 obj=2.03e+01 |delta(obj)|/obj=5.49e-01 nnz(X,L,W)/p=[8.24e+01 4.89e+01 1.10e+02] lns_iter=1
# * iter=7 time=4.05e-02 obj=1.16e+01 |delta(obj)|/obj=7.44e-01 nnz(X,L,W)/p=[8.28e+01 4.94e+01 1.10e+02] lns_iter=1
# * iter
-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=40 time=6.99e-02 obj=-6.59e+01 |delta(obj)|/obj=1.40e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=41 time=7.00e-02 obj=-6.60e+01 |delta(obj)|/obj=1.25e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=42 time=7.49e-02 obj=-6.61e+01 |delta(obj)|/obj=1.23e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=43 time=7.36e-02 obj=-6.62e+01 |delta(obj)|/obj=1.12e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=44 time=7.84e-02 obj=-6.62e+01 |delta(obj)|/obj=1.04e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=45 time=8.39e-02 obj=-6.63e+01 |delta(obj)|/obj=1.00e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# #SQUIC Finished: time=2.70e+00 nnz(X,W)/p=[8.34e+01 1.11e+02]
#
# required time: 2.7
# nnz = 2795 per rows = 25.18
# ✅ Matrix is symmetric per rho 0.02
#
# ----------------------------------------------------------------
#                      SQUIC Version 1.0
# ----------------------------------------------------------------
# Input Matrices
#  nnz(X0)/p:   1.000000e+00
#  nnz(W0)/p:   1.000000e+00
#  nnz(M)/p:    2.763964e+01
#  Y:         111 x 364
# Runtime Configs
#  Sample Cov.:   Deterministic
#  CordDec Vers:  Collective coordinate descent update
#  Inversion:     Approx. block Neumann series
#  Fact. Routine: CHOLMOD
# Parameters
#  verbose:     1
#  lambda:      1.000000e-02
#  max_iter:    100
#  term_tol:    1.000000e-03
#  inv_tol:     1.000000e-04
#  threads:     12
#
# #SQUIC Started
# * compute sample covariance matrix S: nnz(S)/p=8.17e+01 time=6.52e-04
# * iter=1 time=2.74e-03 obj=8.42e+01 |delta(obj)|/obj=3.18e-01 nnz(X,L,W)/p=[8.17e+01 4.94e+01 1.00e+00] lns_iter=7
# * iter=2 time=4.62e-03 obj=7.11e+01 |delta(obj)|/obj=1.84e-01 nnz(X,L,W)/p=[8.17e+01 4.94e+01 9.71e+01] lns_iter=8
# * iter=3 time=2.99e-02 obj=5.33e+01 |delta(obj)|/obj=3.35e-01 nnz(X,L,W)/p=[8.25e+01 4.94e+01 1.08e+02] lns_iter=5
# * iter=4 time=3.16e-02 obj=2.80e+01 |delta(obj)|/obj=9.04e-01 nnz(X,L,W)/p=[8.29e+01 4.94e+01 1.11e+02] lns_iter=3
# * iter=5 time=3.15e-02 obj=1.69e+01 |delta(obj)|/obj=6.55e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.10e+02] lns_iter=1
# * iter=6 time=4.63e-02 obj=5.40e+00 |delta(obj)|/obj=2.13e+00 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=7 time=4.61e-02 obj=-4.19e+00 |delta(obj)|/obj=2.29e+00 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.09e+02] lns_iter=1
# * iter=8 time=4.66e-02 obj=-1.46e+01 |delta(obj)|/obj=7.14e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.08e+02] lns_iter=1
# * iter=9 time=6.04e-02 obj=-2.75e+01 |delta(obj)|/obj=4.68e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.10e+02] lns_iter=1
# * iter=10 time=6.00e-02 obj=-4.08e+01 |delta(obj)|/obj=3.25e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.10e+02] lns_iter=1
# * iter=11 time=6.07e-02 obj=-4.83e+01 |delta(obj)|/obj=1.56e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.10e+02] lns_iter=1
# * iter=12 time=8.92e-02 obj=-5.55e+01 |delta(obj)|/obj=1.31e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=13 time=7.25e-02 obj=-6.20e+01 |delta(obj)|/obj=1.05e-01 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=14 time=7.06e-02 obj=-6.72e+01 |delta(obj)|/obj=7.71e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=15 time=8.37e-02 obj=-7.16e+01 |delta(obj)|/obj=6.07e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=16 time=7.99e-02 obj=-7.49e+01 |delta(obj)|/obj=4.43e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=17 time=8.05e-02 obj=-7.74e+01 |delta(obj)|/obj=3.23e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=18 time=9.06e-02 obj=-8.00e+01 |delta(obj)|/obj=3.28e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=19 time=9.17e-02 obj=-8.21e+01 |delta(obj)|/obj=2.60e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=20 time=9.60e-02 obj=-8.38e+01 |delta(obj)|/obj=2.03e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=21 time=9.51e-02 obj=-8.54e+01 |delta(obj)|/obj=1.83e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=22 time=9.38e-02 obj=-8.68e+01 |delta(obj)|/obj=1.58e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=23 time=8.94e-02 obj=-8.79e+01 |delta(obj)|/obj=1.28e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=24 time=1.05e-01 obj=-8.91e+01 |delta(obj)|/obj=1.32e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=25 time=9.44e-02 obj=-9.00e+01 |delta(obj)|/obj=1.04e-02 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=26 time=9.52e-02 obj=-9.09e+01 |delta(obj)|/obj=9.21e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=27 time=1.20e-01 obj=-9.17e+01 |delta(obj)|/obj=9.08e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=28 time=9.87e-02 obj=-9.24e+01 |delta(obj)|/obj=7.73e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=29 time=9.71e-02 obj=-9.31e+01 |delta(obj)|/obj=6.93e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=30 time=1.05e-01 obj=-9.37e+01 |delta(obj)|/obj=6.59e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=31 time=1.10e-01 obj=-9.42e+01 |delta(obj)|/obj=6.06e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=32 time=1.05e-01 obj=-9.47e+01 |delta(obj)|/obj=5.26e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=33 time=1.17e-01 obj=-9.52e+01 |delta(obj)|/obj=5.18e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=34 time=1.21e-01 obj=-9.57e+01 |delta(obj)|/obj=4.71e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=35 time=1.17e-01 obj=-9.61e+01 |delta(obj)|/obj=4.15e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=36 time=1.28e-01 obj=-9.65e+01 |delta(obj)|/obj=4.07e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=37 time=1.09e-01 obj=-9.68e+01 |delta(obj)|/obj=3.45e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=38 time=1.14e-01 obj=-9.71e+01 |delta(obj)|/obj=3.18e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=39 time=1.29e-01 obj=-9.74e+01 |delta(obj)|/obj=3.08e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=40 time=1.30e-01 obj=-9.77e+01 |delta(obj)|/obj=2.82e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=41 time=1.26e-01 obj=-9.79e+01 |delta(obj)|/obj=2.60e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=42 time=1.31e-01 obj=-9.82e+01 |delta(obj)|/obj=2.50e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=43 time=1.15e-01 obj=-9.84e+01 |delta(obj)|/obj=2.20e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=44 time=1.13e-01 obj=-9.86e+01 |delta(obj)|/obj=1.99e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=45 time=1.18e-01 obj=-9.88e+01 |delta(obj)|/obj=2.00e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=46 time=1.22e-01 obj=-9.90e+01 |delta(obj)|/obj=1.85e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=47 time=1.26e-01 obj=-9.92e+01 |delta(obj)|/obj=1.72e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=48 time=1.30e-01 obj=-9.93e+01 |delta(obj)|/obj=1.67e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=49 time=1.28e-01 obj=-9.95e+01 |delta(obj)|/obj=1.54e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=50 time=1.20e-01 obj=-9.96e+01 |delta(obj)|/obj=1.41e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=51 time=1.29e-01 obj=-9.98e+01 |delta(obj)|/obj=1.40e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=52 time=1.29e-01 obj=-9.99e+01 |delta(obj)|/obj=1.29e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=53 time=1.45e-01 obj=-1.00e+02 |delta(obj)|/obj=1.21e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=54 time=1.43e-01 obj=-1.00e+02 |delta(obj)|/obj=1.14e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=55 time=1.25e-01 obj=-1.00e+02 |delta(obj)|/obj=1.08e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=56 time=1.39e-01 obj=-1.00e+02 |delta(obj)|/obj=1.02e-03 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# * iter=57 time=1.34e-01 obj=-1.00e+02 |delta(obj)|/obj=9.65e-04 nnz(X,L,W)/p=[8.34e+01 4.94e+01 1.11e+02] lns_iter=1
# #SQUIC Finished: time=5.52e+00 nnz(X,W)/p=[8.34e+01 1.11e+02]
#
# required time: 5.53
# nnz = 3271 per rows = 29.47
# ✅ Matrix is symmetric per rho 0.01

# %%
# Use the extracted W for clustering
dict_cluster = clustering(A_matrices)

# Report internal metrics on the clustering
int_metrics = internal_metrics(dict_cluster, A_matrices)
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 130.60it/s]
# /opt/anaconda3/envs/bank/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# No suitable DBSCAN parameters found!
# Best difference in number of clusters: inf
# 100%|██████████| 20/20 [00:00<00:00, 181.54it/s]
# /opt/anaconda3/envs/bank/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# Best params: eps=0.2, min_samples=9
# Best difference in number of clusters: 2.0000
# Best difference in number of clusters: 2.0000
# 100%|██████████| 20/20 [00:00<00:00, 195.99it/s]
# /opt/anaconda3/envs/bank/lib/python3.10/site-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(
# Best params: eps=0.6, min_samples=3
# Best difference in number of clusters: 2.0000
# Best difference in number of clusters: 2.0000
# 100%|██████████| 20/20 [00:00<00:00, 197.31it/s]
# Best params: eps=1.2, min_samples=3
# Best difference in number of clusters: 1.0000
# Best difference in number of clusters: 1.0000
# 100%|██████████| 20/20 [00:00<00:00, 223.50it/s]
# Best params: eps=1.3, min_samples=3
# Best difference in number of clusters: 1.0000
# Best difference in number of clusters: 1.0000
# 100%|██████████| 20/20 [00:00<00:00, 218.11it/s]
# Best params: eps=2.0, min_samples=3
# Best difference in number of clusters: 24.0000
# Best difference in number of clusters: 24.0000
# 100%|██████████| 20/20 [00:00<00:00, 238.69it/s]
# Best params: eps=2.0, min_samples=3
# Best difference in number of clusters: 87.0000
# Best difference in number of clusters: 87.0000
# 100%|██████████| 20/20 [00:00<00:00, 239.19it/s]
# Best params: eps=1.9, min_samples=3
# Best difference in number of clusters: 94.0000
# Best difference in number of clusters: 94.0000

# %%
visualize_metrics(int_metrics)
# Out:
# For rho = 0.9
#     louvain : {'ncut': 2.07, 'rcut': 0.38, 'modularity': 0.2, 'CC': 82, 'nCluster': 86}
#     dbscan : {'ncut': 0.0, 'rcut': 0.0, 'modularity': -0.0, 'CC': 82, 'nCluster': 1}
#     spectral : {'ncut': 9.92, 'rcut': 1.63, 'modularity': 0.1, 'CC': 82, 'nCluster': 86}
#
#
# For rho = 0.5
#     louvain : {'ncut': 1.68, 'rcut': 0.82, 'modularity': 0.42, 'CC': 9, 'nCluster': 13}
#     dbscan : {'ncut': 10.13, 'rcut': 8.26, 'modularity': 0.01, 'CC': 9, 'nCluster': 11}
#     spectral : {'ncut': 6.5, 'rcut': 2.57, 'modularity': 0.36, 'CC': 9, 'nCluster': 13}
#
#
# For rho = 0.2
#     louvain : {'ncut': 1.32, 'rcut': 2.2, 'modularity': 0.44, 'CC': 2, 'nCluster': 6}
#     dbscan : {'ncut': 3.03, 'rcut': 5.56, 'modularity': -0.0, 'CC': 2, 'nCluster': 4}
#     spectral : {'ncut': 1.91, 'rcut': 2.99, 'modularity': 0.43, 'CC': 2, 'nCluster': 6}
#
#
# For rho = 0.1
#     louvain : {'ncut': 2.11, 'rcut': 6.39, 'modularity': 0.41, 'CC': 1, 'nCluster': 6}
#     dbscan : {'ncut': 6.07, 'rcut': 23.76, 'modularity': 0.0, 'CC': 1, 'nCluster': 7}
#     spectral : {'ncut': 2.2, 'rcut': 6.46, 'modularity': 0.38, 'CC': 1, 'nCluster': 6}
#
#
# For rho = 0.09
#     louvain : {'ncut': 2.69, 'rcut': 8.43, 'modularity': 0.4, 'CC': 1, 'nCluster': 6}
#     dbscan : {'ncut': 6.07, 'rcut': 26.14, 'modularity': 0.0, 'CC': 1, 'nCluster': 7}
#     spectral : {'ncut': 2.23, 'rcut': 7.01, 'modularity': 0.38, 'CC': 1, 'nCluster': 6}
#
#
# For rho = 0.05
#     louvain : {'ncut': 2.55, 'rcut': 13.99, 'modularity': 0.36, 'CC': 1, 'nCluster': 6}
#     dbscan : {'ncut': 29.08, 'rcut': 223.75, 'modularity': 0.1, 'CC': 1, 'nCluster': 30}
#     spectral : {'ncut': 2.69, 'rcut': 15.44, 'modularity': 0.32, 'CC': 1, 'nCluster': 6}
#
#
# For rho = 0.02
#     louvain : {'ncut': 2.61, 'rcut': 32.01, 'modularity': 0.29, 'CC': 1, 'nCluster': 5}
#     dbscan : {'ncut': 91.82, 'rcut': 1255.25, 'modularity': -0.0, 'CC': 1, 'nCluster': 92}
#     spectral : {'ncut': 2.4, 'rcut': 27.31, 'modularity': 0.27, 'CC': 1, 'nCluster': 5}
#
#
# For rho = 0.01
#     louvain : {'ncut': 2.79, 'rcut': 62.26, 'modularity': 0.25, 'CC': 1, 'nCluster': 5}
#     dbscan : {'ncut': 98.85, 'rcut': 2198.45, 'modularity': -0.01, 'CC': 1, 'nCluster': 99}
#     spectral : {'ncut': 2.69, 'rcut': 47.74, 'modularity': 0.22, 'CC': 1, 'nCluster': 5}

# %%
# Visualise with cosmograph
widget_dict = visualize_graph_internal(A_matrices, dict_cluster, account_prop)

# %%
rho = 0.5

# %%
widget_dict[rho]['louvain']
# Out:
# Cosmograph(background_color=None, focused_point_ring_color=None, hovered_point_ring_color=None, link_color=Non…

# %%
widget_dict[rho]["spectral"]
# Out:
# Cosmograph(background_color=None, focused_point_ring_color=None, hovered_point_ring_color=None, link_color=Non…

# %%
widget_dict[rho]["dbscan"]
# Out:
# Cosmograph(background_color=None, focused_point_ring_color=None, hovered_point_ring_color=None, link_color=Non…

# %%
lists = extract_results(int_metrics)

# %%
plot_results('ncut', 'N Cut', lists)
plot_results('ncut', 'N Cut', lists, ['louvain', 'spectral'])

# %%
plot_results('rcut', 'Ratio Cut', lists)
plot_results('rcut', 'Ratio Cut', lists, methods=['louvain', 'spectral'])

# %%
plot_results('modularity', 'Modularity', lists)
plot_results('modularity', 'Modularity', lists, methods=['louvain', 'spectral'])

# %%
plot_results('nCluster', 'num Cluster', lists)

# %%
def plot_results_2(metrics, ylabel, results, methods=['louvain', 'spectral', 'dbscan']):
    # Create the plot
    plt.figure(figsize=(6, 6))

    colors = ['steelblue', 'gold', 'indianred']
    dot = ['o-', 's-', '^-']

    if methods == ['louvain', 'spectral']:
        for i, method in enumerate(methods): 
            plt.plot(results['rho_values'], results[f'{method}_{metrics}'], dot[i], label=f'{method}', color=colors[i])
        
        plt.yscale('log')
    
    else:
        plt.plot(results['rho_values'], results[f'louvain_{metrics}'], 'o-', label='Louvain', color=colors[0])
        plt.plot(results['rho_values'], results[f'spectral_{metrics}'], 's-', label='Spectral', color=colors[1])
        plt.plot(results['rho_values'], results[f'dbscan_{metrics}'], '^-', label='DBSCAN', color=colors[2])
    # plt.plot(results['rho_values'], results[f'dbscan_{metrics}'], '^-', color=colors[0])


    plt.xlabel('Reg. Parameter (λ)', fontsize=22)
    plt.ylabel(ylabel, fontsize=22)
    plt.xscale('log')
    plt.yscale('log')
    plt.tick_params(axis='x', labelsize=22)
    plt.tick_params(axis='y', labelsize=22)
    plt.show()

# %%
plot_results_2('CC', 'Connected Components', lists)
